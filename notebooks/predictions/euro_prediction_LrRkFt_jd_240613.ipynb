# %% [markdown]
# # Euro prediction

# %% [markdown]
# ## 0. Settings

# %%
import os

import pandas as pd
import numpy as np
from dotenv import load_dotenv

from psycopg2 import sql, connect
from sqlalchemy import create_engine, text

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from train_test.general import train_test_bookies_comparison, display_train_test_bookies_comparison, train_test
from train_test.split import train_test_split_expanding_windows, train_test_split_sliding_windows
from feature_eng.odds import bookie_prediction, prob_by_bookies
from train_test.metrics import accuracy_fn, classwise_ECE_fn, f_mesure_fn, log_loss_fn, mse_loss_fn, precision_fn, recall_fn
from feature_eng.team_stats import goal_stats, elo_scores, glicko2_scores, trueskill_scores
import datetime

# %% [markdown]
# ### 0.1 Connection

# %%
load_dotenv()
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')

DB_TN_FBREF_RESULTS = os.getenv('DB_TN_FBREF_RESULTS')
DB_TN_SOFIFA_TEAMS_STATS = os.getenv('DB_TN_SOFIFA_TEAMS_STATS')

# %%
connection_url = f'postgresql+psycopg2://{(DB_USER)}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
engine = create_engine(connection_url)

with engine.connect() as connection:
    query = text(f"SELECT * FROM {DB_TN_FBREF_RESULTS}")
    fbref_results_df = pd.read_sql(query, connection)
    sofifa_teams_stats_df = pd.read_sql(f'SELECT * FROM {DB_TN_SOFIFA_TEAMS_STATS}', connection)

# %%
rule_fifa_edition = (sofifa_teams_stats_df["fifa_edition"] == "FC 24")
rule_league_int = (sofifa_teams_stats_df["league"] == "INT")
sofifa_teams_stats_df[rule_fifa_edition & rule_league_int].sort_values(by="update", ascending=False).groupby("team").head(1).sort_values(by="team")
# Out:
#        league                 team  overall  attack  midfield  defence  \
# 2886      INT              Albania       73      66        73       74
# 106599    INT            Argentina       83      85        83       82
# 106600    INT              Belgium       81      82        81       77
# 106601    INT              Croatia       79      77        82       77
# 106602    INT       Czech Republic       75      74        75       75
# 106603    INT              Denmark       79      76        78       79
# 106604    INT              England       85      87        86       83
# 106605    INT              Finland       71      70        71       67
# 106606    INT               France       84      86        85       83
# 3777      INT              Georgia       71      75        70       68
# 106607    INT              Germany       85      81        85       83
# 106608    INT                Ghana       75      74        77       73
# 106609    INT              Hungary       75      76        71       73
# 106610    INT              Iceland       71      74        71       71
# 106611    INT                Italy       82      82        82       82
# 106612    INT               Mexico       77      78        77       74
# 106613    INT              Morocco       78      77        76       79
# 106614    INT          Netherlands       82      82        82       83
# 106615    INT          New Zealand       67      68        67       66
# 106616    INT     Northern Ireland       70      66        69       73
# 106617    INT               Norway       76      83        77       75
# 106618    INT               Poland       77      79        75       74
# 106619    INT             Portugal       84      85        84       83
# 106620    INT                Qatar       69      58        69       68
# 106621    INT  Republic of Ireland       73      73        71       73
# 106622    INT              Romania       72      70        72       71
# 106623    INT             Scotland       76      72        77       76
# 5544      INT             Slovakia       75      73        76       75
# 106624    INT                Spain       83      83        84       83
# 106625    INT               Sweden       77      82        76       74
# 106626    INT              Ukraine       77      81        77       74
# 106627    INT        United States       76      76        76       76
# 106628    INT                Wales       73      74        72       74
#
#         transfer_budget  club_worth build_up_speed build_up_dribbling  ...  \
# 2886                  0         0.0           Slow             Little  ...
# 106599                0         0.0           Slow             Little  ...
# 106600                0         0.0           Slow             Little  ...
# 106601                0         0.0           Slow             Little  ...
# 106602                0         0.0           Slow             Little  ...
# 106603                0         0.0           Slow             Little  ...
# 106604                0         0.0           Slow             Little  ...
# 106605                0         0.0           Slow             Little  ...
# 106606                0         0.0           Slow             Little  ...
# 3777                  0         0.0           Slow             Little  ...
# 106607                0         0.0           Slow             Little  ...
# 106608                0         0.0           Slow             Little  ...
# 106609                0         0.0           Slow             Little  ...
# 106610                0         0.0           Slow             Little  ...
# 106611                0         0.0           Slow             Little  ...
# 106612                0         0.0           Slow             Little  ...
# 106613                0         0.0           Slow             Little  ...
# 106614                0         0.0           Slow             Little  ...
# 106615                0         0.0           Slow             Little  ...
# 106616                0         0.0           Slow             Little  ...
# 106617                0         0.0           Slow             Little  ...
# 106618                0         0.0           Slow             Little  ...
# 106619                0         0.0           Slow             Little  ...
# 106620                0         0.0           Slow             Little  ...
# 106621                0         0.0           Slow             Little  ...
# 106622                0         0.0           Slow             Little  ...
# 106623                0         0.0           Slow             Little  ...
# 5544                  0         0.0           Slow             Little  ...
# 106624                0         0.0           Slow             Little  ...
# 106625                0         0.0           Slow             Little  ...
# 106626                0         0.0           Slow             Little  ...
# 106627                0         0.0           Slow             Little  ...
# 106628                0         0.0           Slow             Little  ...
#
#        defence_pressure defence_team_width defence_defender_line  \
# 2886               Deep             Narrow                 Cover
# 106599             Deep             Narrow                 Cover
# 106600             Deep             Narrow                 Cover
# 106601             Deep             Narrow                 Cover
# 106602             Deep             Narrow                 Cover
# 106603             Deep             Narrow                 Cover
# 106604             Deep             Narrow                 Cover
# 106605             Deep             Narrow                 Cover
# 106606             Deep             Narrow                 Cover
# 3777               Deep             Narrow                 Cover
# 106607             Deep             Narrow                 Cover
# 106608             Deep             Narrow                 Cover
# 106609             Deep             Narrow                 Cover
# 106610             Deep             Narrow                 Cover
# 106611             Deep             Narrow                 Cover
# 106612             Deep             Narrow                 Cover
# 106613             Deep             Narrow                 Cover
# 106614             Deep             Narrow                 Cover
# 106615             Deep             Narrow                 Cover
# 106616             Deep             Narrow                 Cover
# 106617             Deep             Narrow                 Cover
# 106618             Deep             Narrow                 Cover
# 106619             Deep             Narrow                 Cover
# 106620             Deep             Narrow                 Cover
# 106621             Deep             Narrow                 Cover
# 106622             Deep             Narrow                 Cover
# 106623             Deep             Narrow                 Cover
# 5544               Deep             Narrow                 Cover
# 106624             Deep             Narrow                 Cover
# 106625             Deep             Narrow                 Cover
# 106626             Deep             Narrow                 Cover
# 106627             Deep             Narrow                 Cover
# 106628             Deep             Narrow                 Cover
#
#        defence_domestic_prestige international_prestige players  \
# 2886                          10                      2      23
# 106599                        10                      9      26
# 106600                        10                      8      26
# 106601                        10                      6      26
# 106602                        10                      5      26
# 106603                        10                      6      26
# 106604                        10                      8      26
# 106605                        10                      3      26
# 106606                        10                     10      26
# 3777                          10                      2      23
# 106607                        10                     10      26
# 106608                        10                      5      26
# 106609                        10                      4      26
# 106610                        10                      2      26
# 106611                        10                      9      26
# 106612                        10                      7      26
# 106613                        10                      3      26
# 106614                        10                      8      26
# 106615                        10                      2      26
# 106616                        10                      2      26
# 106617                        10                      5      26
# 106618                        10                      5      26
# 106619                        10                      8      26
# 106620                        10                      3      26
# 106621                        10                      5      26
# 106622                        10                      5      26
# 106623                        10                      4      26
# 5544                          10                      3      23
# 106624                        10                      9      26
# 106625                        10                      5      26
# 106626                        10                      6      26
# 106627                        10                      6      26
# 106628                        10                      4      26
#
#        starting_xi_average_age whole_team_average_age fifa_edition     update
# 2886                     27.09                  26.78        FC 24 2024-06-12
# 106599                   28.64                  27.96        FC 24 2024-06-12
# 106600                   27.73                  26.23        FC 24 2024-06-12
# 106601                   27.18                  26.46        FC 24 2024-06-12
# 106602                   25.45                  25.62        FC 24 2024-06-12
# 106603                   27.27                  26.35        FC 24 2024-06-12
# 106604                   26.27                  25.69        FC 24 2024-06-12
# 106605                   28.73                  26.50        FC 24 2024-06-12
# 106606                   27.27                  25.65        FC 24 2024-06-12
# 3777                     26.27                  26.17        FC 24 2024-06-12
# 106607                   27.73                  28.04        FC 24 2024-06-12
# 106608                   26.64                  25.88        FC 24 2024-06-12
# 106609                   26.27                  26.19        FC 24 2024-06-12
# 106610                   27.55                  26.62        FC 24 2024-06-12
# 106611                   28.18                  27.04        FC 24 2024-06-12
# 106612                   26.36                  25.96        FC 24 2024-06-12
# 106613                   26.18                  26.27        FC 24 2024-06-12
# 106614                   26.55                  26.00        FC 24 2024-06-12
# 106615                   25.55                  24.23        FC 24 2024-06-12
# 106616                   27.73                  25.88        FC 24 2024-06-12
# 106617                   25.82                  24.27        FC 24 2024-06-12
# 106618                   26.91                  26.50        FC 24 2024-06-12
# 106619                   26.91                  27.00        FC 24 2024-06-12
# 106620                   27.27                  27.65        FC 24 2024-06-12
# 106621                   24.73                  25.19        FC 24 2024-06-12
# 106622                   26.45                  26.27        FC 24 2024-06-12
# 106623                   26.73                  26.85        FC 24 2024-06-12
# 5544                     29.64                  27.96        FC 24 2024-06-12
# 106624                   27.00                  26.69        FC 24 2024-06-12
# 106625                   26.64                  26.85        FC 24 2024-06-12
# 106626                   24.27                  26.23        FC 24 2024-06-12
# 106627                   25.36                  24.38        FC 24 2024-06-12
# 106628                   26.09                  26.50        FC 24 2024-06-12
#
# [33 rows x 27 columns]

# %%
sofifa_teams_stats_df[sofifa_teams_stats_df["team"] == "France"].sort_values("update", ascending=False)
# Out:
#        league    team  overall  attack  midfield  defence  transfer_budget  \
# 106606    INT  France       84      86        85       83                0
# 85789     INT  France       84      86        85       83                0
# 86134     INT  France       84      86        85       83                0
# 85683     INT  France       84      86        85       83                0
# 86107     INT  France       84      86        85       83                0
# ...       ...     ...      ...     ...       ...      ...              ...
# 85841     INT  France       84      86        85       83                0
# 86082     INT  France       84      86        85       83                0
# 85854     INT  France       84      86        85       83                0
# 85736     INT  France       84      86        85       83                0
# 86106     INT  France       84      86        85       83                0
#
#         club_worth build_up_speed build_up_dribbling  ... defence_pressure  \
# 106606         0.0           Slow             Little  ...             Deep
# 85789          0.0           Slow             Little  ...             Deep
# 86134          0.0           Slow             Little  ...             Deep
# 85683          0.0           Slow             Little  ...             Deep
# 86107          0.0           Slow             Little  ...             Deep
# ...            ...            ...                ...  ...              ...
# 85841          0.0           Slow             Little  ...             Deep
# 86082          0.0           Slow             Little  ...             Deep
# 85854          0.0           Slow             Little  ...             Deep
# 85736          0.0           Slow             Little  ...             Deep
# 86106          0.0           Slow             Little  ...             Deep
#
#        defence_team_width defence_defender_line defence_domestic_prestige  \
# 106606             Narrow                 Cover                        10
# 85789              Narrow                 Cover                        10
# 86134              Narrow                 Cover                        10
# 85683              Narrow                 Cover                        10
# 86107              Narrow                 Cover                        10
# ...                   ...                   ...                       ...
# 85841              Narrow                 Cover                        10
# 86082              Narrow                 Cover                        10
# 85854              Narrow                 Cover                        10
# 85736              Narrow                 Cover                        10
# 86106              Narrow                 Cover                        10
#
#        international_prestige players starting_xi_average_age  \
# 106606                     10      26                   27.27
# 85789                      10      26                   27.27
# 86134                      10      26                   27.27
# 85683                      10      26                   27.27
# 86107                      10      26                   27.27
# ...                       ...     ...                     ...
# 85841                      10      26                   27.27
# 86082                      10      26                   27.27
# 85854                      10      26                   27.27
# 85736                      10      26                   27.27
# 86106                      10      26                   27.27
#
#        whole_team_average_age fifa_edition     update
# 106606                  25.65        FC 24 2024-06-12
# 85789                   25.65        FC 24 2024-05-22
# 86134                   25.65        FC 24 2024-05-08
# 85683                   25.65        FC 24 2024-05-07
# 86107                   25.65        FC 24 2024-04-23
# ...                       ...          ...        ...
# 85841                   25.65      FIFA 09 2008-08-30
# 86082                   25.65      FIFA 08 2008-02-22
# 85854                   25.65      FIFA 08 2007-08-30
# 85736                   25.65      FIFA 07 2007-02-22
# 86106                   25.65      FIFA 07 2006-08-30
#
# [748 rows x 27 columns]

# %%
cond_euro = (fbref_results_df["league"] == "INT-European Championships")
cond_is_coming = (fbref_results_df["date"] >= datetime.date.today())
cond_is_current_season = (fbref_results_df["season"] == "2425")
fbref_results_df[cond_euro & cond_is_current_season]
# Out:
#         game_id                      league season  \
# 85253  b996c4de  INT-European Championships   2425
# 85254  923de563  INT-European Championships   2425
# 85255  94c752b7  INT-European Championships   2425
# 85256  3d8961eb  INT-European Championships   2425
# 85257  bd775264  INT-European Championships   2425
# 85258  c15ec4e7  INT-European Championships   2425
# 85259  4891e62c  INT-European Championships   2425
# 85260      None  INT-European Championships   2425
# 85261      None  INT-European Championships   2425
# 85262      None  INT-European Championships   2425
# 85263      None  INT-European Championships   2425
# 85264      None  INT-European Championships   2425
# 85265  e58cc259  INT-European Championships   2425
# 85266  5bda83ea  INT-European Championships   2425
# 85267  67c17ad9  INT-European Championships   2425
# 85268  5e8192b8  INT-European Championships   2425
# 85269  36e9e40e  INT-European Championships   2425
# 85270  30406358  INT-European Championships   2425
# 85271  248233a8  INT-European Championships   2425
# 85272  5ef87a15  INT-European Championships   2425
# 85282         2024-06-24 Croatia-Italy  Group stage   3.0  Mon  2024-06-24
# 85283        2024-06-25 Denmark-Serbia  Group stage   3.0  Tue  2024-06-25
# 85284      2024-06-25 England-Slovenia  Group stage   3.0  Tue  2024-06-25
# 85285         2024-06-25 France-Poland  Group stage   3.0  Tue  2024-06-25
# 85296       2024-06-22 Belgium-Romania  Group stage   2.0  Sat  2024-06-22
# 85297       2024-06-22 Georgia-Czechia  Group stage   2.0  Sat  2024-06-22
# 85298      2024-06-22 Türkiye-Portugal  Group stage   2.0  Sat  2024-06-22
# 85299      2024-06-23 Scotland-Hungary  Group stage   3.0  Sun  2024-06-23
#
#            time    home_team  ...  attendance                  venue  \
# 85253  18:00:00        Spain  ...     68844.0  Olympiastadion Berlin
# 85254  15:00:00       Poland  ...     48117.0       Volksparkstadion
# 85255  21:00:00       Serbia  ...     48953.0          Veltins-Arena
# 85256  21:00:00      Austria  ...     46425.0      Merkur Spielarena
# 85257  21:00:00      Germany  ...     65052.0          Allianz Arena
# 85258  15:00:00      Hungary  ...     41676.0    RheinEnergieSTADION
# 85259  21:00:00        Italy  ...     60512.0      Signal Iduna Park
# 85260  18:00:00  Netherlands  ...         NaN  Olympiastadion Berlin
# 85261  21:00:00      Czechia  ...         NaN       Volksparkstadion
# 85262  21:00:00      Georgia  ...         NaN          Veltins-Arena
# 85263  18:00:00     Slovakia  ...         NaN     Deutsche Bank Park
# 85264  18:00:00      Ukraine  ...         NaN               MHPArena
# 85265  18:00:00     Slovenia  ...     54000.0               MHPArena
# 85266  18:00:00      Belgium  ...     45181.0     Deutsche Bank Park
# 85267  15:00:00      Romania  ...     61591.0          Allianz Arena
# 85268  21:00:00     Portugal  ...     38421.0         Red Bull Arena
# 85269  18:00:00      Türkiye  ...     59127.0      Signal Iduna Park
# 85270  15:00:00      Croatia  ...     46784.0       Volksparkstadion
# 85271  18:00:00      Germany  ...     54000.0               MHPArena
# 85272  21:00:00     Scotland  ...     42711.0    RheinEnergieSTADION
# 85273  18:00:00      Denmark  ...     46177.0     Deutsche Bank Park
# 85274  15:00:00     Slovenia  ...     63028.0          Allianz Arena
# 85275  21:00:00        Spain  ...     49528.0          Veltins-Arena
# 85276  21:00:00  Netherlands  ...     38531.0         Red Bull Arena
# 85277  18:00:00       Poland  ...     69455.0  Olympiastadion Berlin
# 85278  15:00:00     Slovakia  ...     43910.0      Merkur Spielarena
# 85280  21:00:00  Switzerland  ...     46685.0     Deutsche Bank Park
# 85281  21:00:00      Albania  ...         NaN      Merkur Spielarena
# 85282  21:00:00      Croatia  ...         NaN         Red Bull Arena
# 85283  21:00:00      Denmark  ...         NaN          Allianz Arena
# 85284  21:00:00      England  ...         NaN    RheinEnergieSTADION
# 85285  18:00:00       France  ...         NaN      Signal Iduna Park
# 85296  21:00:00      Belgium  ...     42535.0    RheinEnergieSTADION
# 85297  15:00:00      Georgia  ...     46524.0       Volksparkstadion
# 85298  18:00:00      Türkiye  ...     61047.0      Signal Iduna Park
# 85299  21:00:00     Scotland  ...     54000.0               MHPArena
#
#                  referee                                       match_report  \
# 85253     Michael Oliver  /en/matches/b996c4de/Spain-Croatia-June-15-202...
# 85254  Artur Soares Dias  /en/matches/923de563/Poland-Netherlands-June-1...
# 85255     Daniele Orsato  /en/matches/94c752b7/Serbia-England-June-16-20...
# 85256          Jesús Gil  /en/matches/3d8961eb/Austria-France-June-17-20...
# 85257     Clément Turpin  /en/matches/bd775264/Germany-Scotland-June-14-...
# 85258      Slavko Vinčič  /en/matches/c15ec4e7/Hungary-Switzerland-June-...
# 85259       Felix Zwayer  /en/matches/4891e62c/Italy-Albania-June-15-202...
# 85260               None                                               None
# 85261               None                                               None
# 85262               None                                               None
# 85263               None                                               None
# 85264               None                                               None
# 85265     Sandro Schärer  /en/matches/e58cc259/Slovenia-Denmark-June-16-...
# 85266   Halil Umut Meler  /en/matches/5bda83ea/Belgium-Slovakia-June-17-...
# 85267       Glenn Nyberg  /en/matches/67c17ad9/Romania-Ukraine-June-17-2...
# 85268        Marco Guida  /en/matches/5e8192b8/Portugal-Czechia-June-18-...
# 85269      Facundo Tello  /en/matches/36e9e40e/Turkiye-Georgia-June-18-2...
# 85270  François Letexier  /en/matches/30406358/Croatia-Albania-June-19-2...
# 85271     Danny Makkelie  /en/matches/248233a8/Germany-Hungary-June-19-2...
# 85272      Ivan Kružliak  /en/matches/5ef87a15/Scotland-Switzerland-June...
# 85273  Artur Soares Dias  /en/matches/6cfeccb2/Denmark-England-June-20-2...
# 85274      István Kovács  /en/matches/874a95ef/Slovenia-Serbia-June-20-2...
# 85275      Slavko Vinčič  /en/matches/3f7c6e94/Spain-Italy-June-20-2024-...
# 85276     Anthony Taylor  /en/matches/ad8d106c/Netherlands-France-June-2...
# 85277   Halil Umut Meler  /en/matches/298d4d8f/Poland-Austria-June-21-20...
# 85278     Michael Oliver  /en/matches/73849328/Slovakia-Ukraine-June-21-...
# 85280     Daniele Orsato  /en/matches/14e2c55d/Switzerland-Germany-June-...
# 85281               None                                               None
# 85282               None                                               None
# 85283               None                                               None
# 85284               None                                               None
# 85285               None                                               None
# 85296   Szymon Marciniak  /en/matches/e0d67eb9/Belgium-Romania-June-22-2...
# 85297     Daniel Siebert  /en/matches/aab219f9/Georgia-Czechia-June-22-2...
# 85298       Felix Zwayer  /en/matches/5448c54c/Turkiye-Portugal-June-22-...
# 85299      Facundo Tello  /en/matches/2351343a/Scotland-Hungary-June-23-...
#
#        notes     index away_g home_g away_sat  home_sat
# 85253   None   6360372    0.0    3.0      NaN       NaN
# 85254   None  16295875    2.0    1.0      NaN       NaN
# 85255   None  11528464    1.0    0.0      NaN       NaN
# 85256   None   1556110    1.0    0.0      NaN       NaN
# 85257   None   2483190    1.0    5.0      NaN       NaN
# 85258   None  11705248    3.0    1.0      NaN       NaN
# 85259   None  14297509    1.0    2.0      NaN       NaN
# 85260   None  12042657    NaN    NaN      NaN       NaN
# 85261   None   2598241    NaN    NaN      NaN       NaN
# 85262   None  10115670    NaN    NaN      NaN       NaN
# 85263   None  10264785    NaN    NaN      NaN       NaN
# 85264   None    729627    NaN    NaN      NaN       NaN
# 85265   None   2921792    1.0    1.0      NaN       NaN
# 85266   None   8817969    1.0    0.0      NaN       NaN
# 85267   None  13000659    0.0    3.0      NaN       NaN
# 85268   None   4213200    1.0    2.0      NaN       NaN
# 85269   None  12399256    1.0    3.0      NaN       NaN
# 85270   None  11393706    2.0    2.0      NaN       NaN
# 85271   None   9605620    0.0    2.0      NaN       NaN
# 85272   None   6634336    1.0    1.0      NaN       NaN
# 85273   None   3199265    1.0    1.0      NaN       NaN
# 85274   None   5245428    1.0    1.0      NaN       NaN
# 85275   None  14328916    0.0    1.0      NaN       NaN
# 85276   None  12083537    0.0    0.0      NaN       NaN
# 85277   None  15083623    3.0    1.0      NaN       NaN
# 85278   None   4160791    2.0    1.0      NaN       NaN
# 85280   None   9999774    1.0    1.0      NaN       NaN
# 85281   None  14498120    NaN    NaN      NaN       NaN
# 85282   None   9107911    NaN    NaN      NaN       NaN
# 85283   None  10483043    NaN    NaN      NaN       NaN
# 85284   None   6133745    NaN    NaN      NaN       NaN
# 85285   None  13640449    NaN    NaN      NaN       NaN
# 85296   None   2516083    0.0    2.0      NaN       NaN
# 85297   None   6418451    1.0    1.0      NaN       NaN
# 85298   None   4099055    3.0    0.0      NaN       NaN
# 85299   None  16363446    1.0    0.0      NaN       NaN
#
# [36 rows x 24 columns]

# %%
mapping = {
    'VfL Bochum 1848': 'Bochum',
    'Tottenham Hotspur': 'Tottenham',
    'Paris Saint Germain': 'Paris S-G',
    'FC Köln': 'Köln',
    'Real Zaragoza': 'Zaragoza',
    'Wolverhampton Wanderers': 'Wolves',
    'Sheffield United': 'Sheffield Utd',
    'Amiens SC': 'Amiens',
    'FSV Mainz 05': 'Mainz 05',
    'Paderborn': 'Paderborn 07',
    'Bolton Wanderers': 'Bolton',
    'Huddersfield Town': 'Huddersfield',
    'Olympique de Marseille': 'Marseille',
    'LOSC Lille': 'Lille',
    'Grenoble Foot 38': 'Grenoble',
    'Racing Santander': 'Racing Sant',
    'Eintracht Frankfurt': 'Eint Frankfurt',
    'Fortuna Düsseldorf': 'Düsseldorf',
    'Queens Park Rangers': 'QPR',
    'SC Freiburg': 'Freiburg',
    'DSC Arminia Bielefeld': 'Arminia',
    'Republic of Ireland': 'Rep. of Ireland',
    'Evian TG': 'Evian',
    'FC Barcelona': 'Barcelona',
    'Brighton & Hove Albion': 'Brighton',
    'Deportivo La Coruña': 'La Coruña',
    'Angers SCO': 'Angers',
    'West Ham United': 'West Ham',
    'VfL Wolfsburg': 'Wolfsburg',
    'FC Augsburg': 'Augsburg',
    'India': 'India',
    'Bari 1908': 'Bari',
    'Czech Republic': 'Czechia',
    'Nottingham Forest': "Nott'ham Forest",
    'Newcastle United': 'Newcastle Utd',
    'Borussia Dortmund': 'Dortmund',
    'AFC Bournemouth': 'Bournemouth',
    'Iran': 'IR Iran',
    'Borussia Mönchengladbach': 'Gladbach',
    'Olympique Lyonnais': 'Lyon',
    'Venezuela': 'Venezuela',
    'TSG Hoffenheim': 'Hoffenheim',
    'SD Eibar': 'Eibar',
    'West Bromwich Albion': 'West Brom',
    'VfB Stuttgart': 'Stuttgart',
    'Arles': 'Arles-Avignon',
    'Stade de Reims ': 'Reims',
    'Stade Brestois 29': 'Brest',
    'Real Valladolid': 'Valladolid',
    'Clermont': 'Clermont Foot',
    'FC Union Berlin': 'Union Berlin',
    'Manchester United': 'Manchester Utd',
    'Deportivo Alavés': 'Alavés',
    'Celta de Vigo': 'Celta Vigo',
    'Bayer 04 Leverkusen': 'Leverkusen',
    'FC Bayern München': 'Bayern Munich',
    'SpVgg Greuther Fürth': 'Greuther Fürth',
    'Ingolstadt': 'Ingolstadt 04',
    'Eintracht Braunschweig': 'Braunschweig',
    'Blackburn Rovers': 'Blackburn'
}

# Appliquer le mapping au DataFrame sofifa_teams_stats_df
sofifa_teams_stats_df['team'] = sofifa_teams_stats_df['team'].replace(mapping)
                                                                      
fbref_results_df['date'] = pd.to_datetime(fbref_results_df['date'])
fbref_results_df_date = fbref_results_df[fbref_results_df["date"] >= min(sofifa_teams_stats_df["update"])]

# %%
cond_euro = (fbref_results_df["league"] == "INT-European Championships")
cond_is_coming = (fbref_results_df["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_results_df["season"] == "2425")
fbref_results_df[cond_euro & cond_is_current_season]["league"].count()
# Out:
# 36

# %%
# Display teams that are not in sofifa_teams_stats_df
cond_euro = (fbref_results_df["league"] == "INT-European Championships")
cond_is_coming = (fbref_results_df["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_results_df["season"] == "2425")
team_euro_fbref = set(fbref_results_df[cond_euro & cond_is_current_season]['home_team'].unique()).union(set(fbref_results_df[cond_euro & cond_is_current_season]['away_team'].unique()))

# %%
len(team_euro_fbref)
# Out:
# 24

# %%
sofifa_teams = set(sofifa_teams_stats_df[sofifa_teams_stats_df["league"] == "INT"]['team'].unique())
sofifa_teams
# Out:
# {'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Bolivia',
#  'Brazil',
#  'Bulgaria',
#  'Cameroon',
#  'Canada',
#  'Chile',
#  'China PR',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Czechia',
#  "Côte d'Ivoire",
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'England',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Hungary',
#  'IR Iran',
#  'Iceland',
#  'India',
#  'Italy',
#  'Japan',
#  'Korea Republic',
#  'Mexico',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Northern Ireland',
#  'Norway',
#  'Paraguay',
#  'Peru',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Rep. of Ireland',
#  'Romania',
#  'Russia',
#  'Saudi Arabia',
#  'Scotland',
#  'Senegal',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tunisia',
#  'Türkiye',
#  'Ukraine',
#  'United States',
#  'Uruguay',
#  'Venezuela',
#  'Wales'}

# %%
[team for team in team_euro_fbref if team not in sofifa_teams]
# Out:
# []

# %%
# Extraire la liste des équipes du DataFrame sofifa_teams_stats_df
sofifa_teams = set(sofifa_teams_stats_df['team'].unique())

# Filtrer les lignes de fbref_results_df
fbref_df_date_filtered = fbref_results_df_date[
    (fbref_results_df_date['home_team'].isin(sofifa_teams)) & 
    (fbref_results_df_date['away_team'].isin(sofifa_teams))
]

# Afficher les informations du DataFrame filtré
fbref_df_date_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31751 entries, 15862 to 87040
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       31741 non-null  object
#  1   league        31751 non-null  object
#  2   season        31751 non-null  object
#  3   game          31751 non-null  object
#  4   round         6089 non-null   object
#  5   week          31618 non-null  float64
#  6   day           31751 non-null  object
#  7   date          31751 non-null  datetime64[ns]
#  8   time          18191 non-null  object
#  9   home_team     31751 non-null  object
#  10  home_xg       12513 non-null  float64
#  11  score         31640 non-null  object
#  12  away_xg       12513 non-null  float64
#  13  away_team     31751 non-null  object
#  14  attendance    18470 non-null  float64
#  15  venue         26712 non-null  object
#  16  referee       31562 non-null  object
#  17  match_report  31741 non-null  object
#  18  notes         171 non-null    object
#  19  index         31751 non-null  int64
#  20  away_g        31640 non-null  float64
#  21  home_g        31640 non-null  float64
#  22  away_sat      28 non-null     float64
#  23  home_sat      28 non-null     float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(14)
# memory usage: 6.1+ MB

# %%
# Display teams that are not in sofifa_teams_stats_df
cond_euro = (fbref_df_date_filtered["league"] == "INT-European Championships")
cond_is_coming = (fbref_df_date_filtered["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_df_date_filtered["season"] == "2425")
len(set(fbref_df_date_filtered[cond_euro & cond_is_current_season]['home_team'].unique()))
# Out:
# 24

# %%
cond_euro = (fbref_df_date_filtered["league"] == "INT-European Championships")
cond_is_coming = (fbref_df_date_filtered["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_df_date_filtered["season"] == "2425")
fbref_df_date_filtered[cond_euro & cond_is_current_season]["league"].count()
# Out:
# 36

# %%
import pandas as pd

# Assurez-vous que les dates sont correctement formatées
fbref_df_date_filtered['date'] = pd.to_datetime(fbref_df_date_filtered['date'])
sofifa_teams_stats_df['update'] = pd.to_datetime(sofifa_teams_stats_df['update'])

# Trier les dataframes pour la jointure asynchrone
fbref_df_date_filtered = fbref_df_date_filtered.sort_values(by='date')
sofifa_teams_stats_df = sofifa_teams_stats_df.sort_values(by='update')

# Effectuer une jointure asynchrone pour les équipes à domicile
home_stats = pd.merge_asof(
    fbref_df_date_filtered[['home_team', 'date']].rename(columns={'home_team': 'team', 'date': 'match_date'}),
    sofifa_teams_stats_df,
    left_on='match_date',
    right_on='update',
    by='team',
    direction='backward'
).drop(columns=['team', 'match_date'])

# Renommer les colonnes pour éviter les conflits
home_stats.columns = ['home_' + col for col in home_stats.columns]

# Effectuer une jointure asynchrone pour les équipes à l'extérieur
away_stats = pd.merge_asof(
    fbref_df_date_filtered[['away_team', 'date']].rename(columns={'away_team': 'team', 'date': 'match_date'}),
    sofifa_teams_stats_df,
    left_on='match_date',
    right_on='update',
    by='team',
    direction='backward'
).drop(columns=['team', 'match_date'])

# Renommer les colonnes pour éviter les conflits
away_stats.columns = ['away_' + col for col in away_stats.columns]

# Fusionner les stats avec le dataframe initial
fbref_df_date_filtered_concat = pd.concat([fbref_df_date_filtered.reset_index(drop=True), home_stats.reset_index(drop=True), away_stats.reset_index(drop=True)], axis=1)
# Out:
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3577012350.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered['date'] = pd.to_datetime(fbref_df_date_filtered['date'])

# %%
fbref_df_date_filtered_concat['FTR'] = fbref_df_date_filtered_concat.apply(lambda x: 1 if x['home_g'] > x['away_g'] else 0 if x['home_g'] == x['away_g'] else -1 if x['home_g'] < x['away_g'] else None, axis=1)

# %%
# Drop rows if overall_away is nan or overall_home is nan
import datetime
start_euro = datetime.datetime(2024, 6, 14)
fbref_df_date_filtered_concat_no_nan = fbref_df_date_filtered_concat.dropna(subset=['home_overall', 'away_overall'])
fbref_df_date_filtered_concat_no_nan = fbref_df_date_filtered_concat_no_nan[(fbref_df_date_filtered_concat_no_nan['FTR'].notnull()) | (fbref_df_date_filtered_concat_no_nan['date'] >= start_euro)]
fbref_df_date_filtered_concat_no_nan
# Out:
#         game_id                      league season  \
# 0      880e137f          ENG-Premier League   0607
# 1      60c88132                 FRA-Ligue 1   0607
# 7      4742f790          ENG-Premier League   0607
# 9      dc45f23c          ENG-Premier League   0607
# 14     36cd8447                 ITA-Serie A   0607
# ...         ...                         ...    ...
# 31746      None  INT-European Championships   2425
# 31747      None  INT-European Championships   2425
# 31748      None  INT-European Championships   2425
# 31749      None  INT-European Championships   2425
# 31750      None  INT-European Championships   2425
#
#                                       game        round  week  day       date  \
# 0             2006-09-09 Everton-Liverpool         None   4.0  Sat 2006-09-09
# 1                  2006-09-09 Nantes-Lille         None   5.0  Sat 2006-09-09
# 7          2006-09-09 Newcastle Utd-Fulham         None   4.0  Sat 2006-09-09
# 9      2006-09-09 Manchester Utd-Tottenham         None   4.0  Sat 2006-09-09
# 14             2006-09-09 Fiorentina-Inter         None   1.0  Sat 2006-09-09
# ...                                    ...          ...   ...  ...        ...
# 31746       2024-06-25 Netherlands-Austria  Group stage   3.0  Tue 2024-06-25
# 31747           2024-06-26 Czechia-Türkiye  Group stage   3.0  Wed 2024-06-26
# 31748          2024-06-26 Slovakia-Romania  Group stage   3.0  Wed 2024-06-26
# 31749           2024-06-26 Ukraine-Belgium  Group stage   3.0  Wed 2024-06-26
# 31750          2024-06-26 Georgia-Portugal  Group stage   3.0  Wed 2024-06-26
#
#            time       home_team  ...  away_defence_team_width  \
# 0          None         Everton  ...                   Narrow
# 1          None          Nantes  ...                   Narrow
# 7          None   Newcastle Utd  ...                   Narrow
# 9          None  Manchester Utd  ...                   Narrow
# 14         None      Fiorentina  ...                   Narrow
# ...         ...             ...  ...                      ...
# 31746  18:00:00     Netherlands  ...                   Narrow
# 31747  21:00:00         Czechia  ...                   Narrow
# 31748  18:00:00        Slovakia  ...                   Narrow
# 31749  18:00:00         Ukraine  ...                   Narrow
# 31750  21:00:00         Georgia  ...                   Narrow
#
#       away_defence_defender_line  away_defence_domestic_prestige  \
# 0                          Cover                             9.0
# 1                          Cover                             6.0
# 7                          Cover                             5.0
# 9                          Cover                             7.0
# 14                         Cover                            10.0
# ...                          ...                             ...
# 31746                      Cover                            10.0
# 31747                      Cover                            10.0
# 31748                      Cover                            10.0
# 31749                      Cover                            10.0
# 31750                      Cover                            10.0
#
#       away_international_prestige  away_players away_starting_xi_average_age  \
# 0                             9.0          33.0                        26.27
# 1                             4.0          26.0                        23.91
# 7                             2.0          31.0                        26.55
# 9                             7.0          31.0                        24.55
# 14                            8.0          26.0                        28.82
# ...                           ...           ...                          ...
# 31746                         4.0          23.0                        25.82
# 31747                         6.0          23.0                        25.18
# 31748                         5.0          26.0                        26.45
# 31749                         8.0          26.0                        27.73
# 31750                         8.0          26.0                        26.91
#
#       away_whole_team_average_age away_fifa_edition away_update  FTR
# 0                           23.76           FIFA 07  2006-08-30  1.0
# 1                           24.27           FIFA 07  2006-08-30  0.0
# 7                           25.29           FIFA 07  2006-08-30 -1.0
# 9                           23.74           FIFA 07  2006-08-30  1.0
# 14                          27.77           FIFA 07  2006-08-30 -1.0
# ...                           ...               ...         ...  ...
# 31746                       25.87           FIFA 23  2023-09-11  NaN
# 31747                       24.09           FIFA 21  2021-09-25  NaN
# 31748                       26.27             FC 24  2024-06-12  NaN
# 31749                       26.23             FC 24  2024-06-12  NaN
# 31750                       27.00             FC 24  2024-06-12  NaN
#
# [28609 rows x 77 columns]

# %%
cond_euro = (fbref_df_date_filtered_concat["league"] == "INT-European Championships")
cond_is_coming = (fbref_df_date_filtered_concat["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_df_date_filtered_concat["season"] == "2425")
fbref_df_date_filtered_concat[cond_euro & cond_is_current_season]
# Out:
#         game_id                      league season  \
# 31715  bd775264  INT-European Championships   2425
# 31716  b996c4de  INT-European Championships   2425
# 31717  c15ec4e7  INT-European Championships   2425
# 31718  4891e62c  INT-European Championships   2425
# 31719  923de563  INT-European Championships   2425
# 31720  94c752b7  INT-European Championships   2425
# 31721  e58cc259  INT-European Championships   2425
# 31722  5bda83ea  INT-European Championships   2425
# 31723  3d8961eb  INT-European Championships   2425
# 31724  67c17ad9  INT-European Championships   2425
# 31725  5e8192b8  INT-European Championships   2425
# 31726  36e9e40e  INT-European Championships   2425
# 31727  5ef87a15  INT-European Championships   2425
# 31728  248233a8  INT-European Championships   2425
# 31729  30406358  INT-European Championships   2425
# 31730  6cfeccb2  INT-European Championships   2425
# 31731  874a95ef  INT-European Championships   2425
# 31732  3f7c6e94  INT-European Championships   2425
# 31733  ad8d106c  INT-European Championships   2425
# 31734  298d4d8f  INT-European Championships   2425
# 31735  73849328  INT-European Championships   2425
# 31736  e0d67eb9  INT-European Championships   2425
# 31737  aab219f9  INT-European Championships   2425
# 31738  5448c54c  INT-European Championships   2425
# 31739  2351343a  INT-European Championships   2425
# 31740  14e2c55d  INT-European Championships   2425
# 31741      None  INT-European Championships   2425
# 31742      None  INT-European Championships   2425
# 31743      None  INT-European Championships   2425
# 31744      None  INT-European Championships   2425
# 31745      None  INT-European Championships   2425
# 31750      2024-06-26 Georgia-Portugal  Group stage   3.0  Wed 2024-06-26
#
#            time    home_team  ...  away_defence_team_width  \
# 31715  21:00:00      Germany  ...                   Narrow
# 31716  18:00:00        Spain  ...                   Narrow
# 31717  15:00:00      Hungary  ...                   Narrow
# 31718  21:00:00        Italy  ...                   Narrow
# 31719  15:00:00       Poland  ...                   Narrow
# 31720  21:00:00       Serbia  ...                   Narrow
# 31721  18:00:00     Slovenia  ...                   Narrow
# 31722  18:00:00      Belgium  ...                   Narrow
# 31723  21:00:00      Austria  ...                   Narrow
# 31724  15:00:00      Romania  ...                   Narrow
# 31725  21:00:00     Portugal  ...                   Narrow
# 31726  18:00:00      Türkiye  ...                   Narrow
# 31727  21:00:00     Scotland  ...                   Narrow
# 31728  18:00:00      Germany  ...                   Narrow
# 31729  15:00:00      Croatia  ...                   Narrow
# 31730  18:00:00      Denmark  ...                   Narrow
# 31731  15:00:00     Slovenia  ...                   Narrow
# 31732  21:00:00        Spain  ...                   Narrow
# 31733  21:00:00  Netherlands  ...                   Narrow
# 31734  18:00:00       Poland  ...                   Narrow
# 31735  15:00:00     Slovakia  ...                   Narrow
# 31736  21:00:00      Belgium  ...                   Narrow
# 31737  15:00:00      Georgia  ...                   Narrow
# 31738  18:00:00      Türkiye  ...                   Narrow
# 31739  21:00:00     Scotland  ...                   Narrow
# 31740  21:00:00  Switzerland  ...                   Narrow
# 31741  21:00:00      Albania  ...                   Narrow
# 31742  21:00:00      Croatia  ...                   Narrow
# 31743  21:00:00      England  ...                   Narrow
# 31744  18:00:00       France  ...                   Narrow
# 31745  21:00:00      Denmark  ...                   Narrow
# 31746  18:00:00  Netherlands  ...                   Narrow
# 31747  21:00:00      Czechia  ...                   Narrow
# 31748  18:00:00     Slovakia  ...                   Narrow
# 31749  18:00:00      Ukraine  ...                   Narrow
# 31750  21:00:00      Georgia  ...                   Narrow
#
#       away_defence_defender_line  away_defence_domestic_prestige  \
# 31715                      Cover                            10.0
# 31716                      Cover                            10.0
# 31717                      Cover                            10.0
# 31718                      Cover                            10.0
# 31719                      Cover                            10.0
# 31720                      Cover                            10.0
# 31721                      Cover                            10.0
# 31722                      Cover                            10.0
# 31723                      Cover                            10.0
# 31724                      Cover                            10.0
# 31725                      Cover                            10.0
# 31726                      Cover                            10.0
# 31727                      Cover                            10.0
# 31728                      Cover                            10.0
# 31729                      Cover                            10.0
# 31730                      Cover                            10.0
# 31731                      Cover                            10.0
# 31732                      Cover                            10.0
# 31733                      Cover                            10.0
# 31734                      Cover                            10.0
# 31735                      Cover                            10.0
# 31736                      Cover                            10.0
# 31737                      Cover                            10.0
# 31738                      Cover                            10.0
# 31739                      Cover                            10.0
# 31740                      Cover                            10.0
# 31741                      Cover                            10.0
# 31742                      Cover                            10.0
# 31743                      Cover                            10.0
# 31744                      Cover                            10.0
# 31745                      Cover                            10.0
# 31746                      Cover                            10.0
# 31747                      Cover                            10.0
# 31748                      Cover                            10.0
# 31749                      Cover                            10.0
# 31750                      Cover                            10.0
#
# 31745                       26.46           FIFA 23  2022-11-20  NaN
# 31746                       25.87           FIFA 23  2023-09-11  NaN
# 31747                       24.09           FIFA 21  2021-09-25  NaN
# 31748                       26.27             FC 24  2024-06-12  NaN
# 31749                       26.23             FC 24  2024-06-12  NaN
# 31750                       27.00             FC 24  2024-06-12  NaN
#
# [36 rows x 77 columns]

# %%
fbref_df_date_filtered_concat_no_nan[fbref_df_date_filtered_concat_no_nan['score'].isnull()]
# Out:
#       game_id                      league season  \
# 31741    None  INT-European Championships   2425
# 31742    None  INT-European Championships   2425
# 31743    None  INT-European Championships   2425
# 31744    None  INT-European Championships   2425
# 31745    None  INT-European Championships   2425
# 31746    None  INT-European Championships   2425
# 31747    None  INT-European Championships   2425
# 31748    None  INT-European Championships   2425
# 31749    None  INT-European Championships   2425
# 31750    None  INT-European Championships   2425
#
#                                  game        round  week  day       date  \
# 31741        2024-06-24 Albania-Spain  Group stage   3.0  Mon 2024-06-24
# 31742        2024-06-24 Croatia-Italy  Group stage   3.0  Mon 2024-06-24
# 31743     2024-06-25 England-Slovenia  Group stage   3.0  Tue 2024-06-25
# 31744        2024-06-25 France-Poland  Group stage   3.0  Tue 2024-06-25
# 31745       2024-06-25 Denmark-Serbia  Group stage   3.0  Tue 2024-06-25
# 31746  2024-06-25 Netherlands-Austria  Group stage   3.0  Tue 2024-06-25
# 31747      2024-06-26 Czechia-Türkiye  Group stage   3.0  Wed 2024-06-26
# 31748     2024-06-26 Slovakia-Romania  Group stage   3.0  Wed 2024-06-26
# 31749      2024-06-26 Ukraine-Belgium  Group stage   3.0  Wed 2024-06-26
# 31750     2024-06-26 Georgia-Portugal  Group stage   3.0  Wed 2024-06-26
#
#            time    home_team  ...  away_defence_team_width  \
# 31741  21:00:00      Albania  ...                   Narrow
# 31742  21:00:00      Croatia  ...                   Narrow
# 31743  21:00:00      England  ...                   Narrow
# 31744  18:00:00       France  ...                   Narrow
# 31745  21:00:00      Denmark  ...                   Narrow
# 31746  18:00:00  Netherlands  ...                   Narrow
# 31747  21:00:00      Czechia  ...                   Narrow
# 31748  18:00:00     Slovakia  ...                   Narrow
# 31749  18:00:00      Ukraine  ...                   Narrow
# 31750  21:00:00      Georgia  ...                   Narrow
#
#       away_defence_defender_line  away_defence_domestic_prestige  \
# 31741                      Cover                            10.0
# 31742                      Cover                            10.0
# 31743                      Cover                            10.0
# 31744                      Cover                            10.0
# 31745                      Cover                            10.0
# 31746                      Cover                            10.0
# 31747                      Cover                            10.0
# 31748                      Cover                            10.0
# 31749                      Cover                            10.0
# 31750                      Cover                            10.0
#
#       away_international_prestige  away_players away_starting_xi_average_age  \
# 31741                         9.0          26.0                        27.00
# 31742                         9.0          26.0                        28.18
# 31743                         5.0          23.0                        26.64
# 31744                         5.0          26.0                        26.91
# 31745                         6.0          26.0                        26.36
# 31746                         4.0          23.0                        25.82
# 31747                         6.0          23.0                        25.18
# 31748                         5.0          26.0                        26.45
# 31749                         8.0          26.0                        27.73
# 31750                         8.0          26.0                        26.91
#
#       away_whole_team_average_age away_fifa_edition away_update  FTR
# 31741                       26.69             FC 24  2024-06-12  NaN
# 31742                       27.04             FC 24  2024-06-12  NaN
# 31743                       26.30           FIFA 21  2021-09-25  NaN
# 31744                       26.50             FC 24  2024-06-12  NaN
# 31745                       26.46           FIFA 23  2022-11-20  NaN
# 31746                       25.87           FIFA 23  2023-09-11  NaN
# 31747                       24.09           FIFA 21  2021-09-25  NaN
# 31748                       26.27             FC 24  2024-06-12  NaN
# 31749                       26.23             FC 24  2024-06-12  NaN
# 31750                       27.00             FC 24  2024-06-12  NaN
#
# [10 rows x 77 columns]

# %%
date_stop = datetime.datetime(2024, 6, 13)
elo_scores(fbref_df_date_filtered_concat_no_nan, home_team_id_col='home_team', away_team_id_col='away_team', home_team_goal_col='home_g', away_team_goal_col='away_g', date_stop=date_stop)
goal_stats(fbref_df_date_filtered_concat_no_nan, home_team_id_col='home_team', away_team_id_col='away_team', home_team_goal_col='home_g', away_team_goal_col='away_g', date_stop=date_stop)
glicko2_scores(fbref_df_date_filtered_concat_no_nan, home_team_id_col='home_team', away_team_id_col='away_team', home_team_goal_col='home_g', away_team_goal_col='away_g', date_stop=date_stop)
trueskill_scores(fbref_df_date_filtered_concat_no_nan, home_team_id_col='home_team', away_team_id_col='away_team', home_team_goal_col='home_g', away_team_goal_col='away_g', date_stop=date_stop)

# %%
cond_euro = (fbref_df_date_filtered_concat_no_nan["league"] == "INT-European Championships")
cond_is_coming = (fbref_df_date_filtered_concat_no_nan["date"] >= datetime.datetime.now())
cond_is_current_season = (fbref_df_date_filtered_concat_no_nan["season"] == "2425")
cols = ['game', 'week', 'date',
       'time', 'home_team', 'score', 'away_team',
       'FTR', 'elo_home_before', 'elo_away_before',
       'home_team_goals_season_to_date_before_match',
       'away_team_goals_season_to_date_before_match',
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'avg_home_team_goals_season_to_date_before_match',
       'avg_away_team_goals_season_to_date_before_match',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']
fbref_df_date_filtered_concat_no_nan[cond_euro & cond_is_current_season][cols]
# Out:
#                                   game  week       date      time  \
# 31715      2024-06-14 Germany-Scotland   1.0 2024-06-14  21:00:00
# 31716         2024-06-15 Spain-Croatia   1.0 2024-06-15  18:00:00
# 31717   2024-06-15 Hungary-Switzerland   1.0 2024-06-15  15:00:00
# 31718         2024-06-15 Italy-Albania   1.0 2024-06-15  21:00:00
# 31719    2024-06-16 Poland-Netherlands   1.0 2024-06-16  15:00:00
# 31720        2024-06-16 Serbia-England   1.0 2024-06-16  21:00:00
# 31721      2024-06-16 Slovenia-Denmark   1.0 2024-06-16  18:00:00
# 31722      2024-06-17 Belgium-Slovakia   1.0 2024-06-17  18:00:00
# 31723        2024-06-17 Austria-France   1.0 2024-06-17  21:00:00
# 31724       2024-06-17 Romania-Ukraine   1.0 2024-06-17  15:00:00
# 31725      2024-06-18 Portugal-Czechia   1.0 2024-06-18  21:00:00
# 31739                 0.059995                 0.059986
# 31740                 0.059976                 0.059982
# 31741                 0.060000                 0.059958
# 31742                 0.059969                 0.059972
# 31743                 0.059975                 0.059998
# 31744                 0.059974                 0.059975
# 31745                 0.059988                 0.059995
# 31746                 0.059987                 0.059995
# 31747                 0.059994                 0.059997
# 31748                 0.060000                 0.059993
# 31749                 0.059998                 0.059992
# 31750                 0.060000                 0.059974
#
#        trueskill_home_before  trueskill_away_before
# 31715                    0.0                    0.0
# 31716                    0.0                    0.0
# 31717                    0.0                    0.0
# 31718                    0.0                    0.0
# 31719                    0.0                    0.0
# 31720                    0.0                    0.0
# 31721                    0.0                    0.0
# 31722                    0.0                    0.0
# 31723                    0.0                    0.0
# 31724                    0.0                    0.0
# 31725                    0.0                    0.0
# 31726                    0.0                    0.0
# 31727                    0.0                    0.0
# 31728                    0.0                    0.0
# 31729                    0.0                    0.0
# 31730                    0.0                    0.0
# 31731                    0.0                    0.0
# 31732                    0.0                    0.0
# 31733                    0.0                    0.0
# 31734                    0.0                    0.0
# 31735                    0.0                    0.0
# 31736                    0.0                    0.0
# 31737                    0.0                    0.0
# 31738                    0.0                    0.0
# 31739                    0.0                    0.0
# 31740                    0.0                    0.0
# 31741                    0.0                    0.0
# 31742                    0.0                    0.0
# 31743                    0.0                    0.0
# 31744                    0.0                    0.0
# 31745                    0.0                    0.0
# 31746                    0.0                    0.0
# 31747                    0.0                    0.0
# 31748                    0.0                    0.0
# 31749                    0.0                    0.0
# 31750                    0.0                    0.0
#
# [36 rows x 24 columns]

# %%
fbref_df_date_filtered_concat_no_nan.columns
# Out:
# Index(['game_id', 'league', 'season', 'game', 'round', 'week', 'day', 'date',
#        'time', 'home_team', 'home_xg', 'score', 'away_xg', 'away_team',
#        'attendance', 'venue', 'referee', 'match_report', 'notes', 'index',
#        'away_g', 'home_g', 'away_sat', 'home_sat', 'home_league',
#        'home_overall', 'home_attack', 'home_midfield', 'home_defence',
#        'home_transfer_budget', 'home_club_worth', 'home_build_up_speed',
#        'home_build_up_dribbling', 'home_build_up_passing',
#        'home_build_up_positioning', 'home_chance_creation_crossing',
#        'home_chance_creation_passing', 'home_chance_creation_shooting',
#        'home_chance_creation_positioning', 'home_defence_aggression',
#        'home_defence_pressure', 'home_defence_team_width',
#        'home_defence_defender_line', 'home_defence_domestic_prestige',
#        'home_international_prestige', 'home_players',
#        'home_starting_xi_average_age', 'home_whole_team_average_age',
#        'home_fifa_edition', 'home_update', 'away_league', 'away_overall',
#        'away_attack', 'away_midfield', 'away_defence', 'away_transfer_budget',
#        'away_club_worth', 'away_build_up_speed', 'away_build_up_dribbling',
#        'away_build_up_passing', 'away_build_up_positioning',
#        'away_chance_creation_crossing', 'away_chance_creation_passing',
#        'away_chance_creation_shooting', 'away_chance_creation_positioning',
#        'away_defence_aggression', 'away_defence_pressure',
#        'away_defence_team_width', 'away_defence_defender_line',
#        'away_defence_domestic_prestige', 'away_international_prestige',
#        'away_players', 'away_starting_xi_average_age',
#        'away_whole_team_average_age', 'away_fifa_edition', 'away_update',
#        'FTR', 'elo_home_before', 'elo_away_before',
#        'home_team_goals_season_to_date_before_match',
#        'away_team_goals_season_to_date_before_match',
#        'home_team_number_of_match_played', 'away_team_number_of_match_played',
#        'avg_home_team_goals_season_to_date_before_match',
#        'avg_away_team_goals_season_to_date_before_match',
#        'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
#        'glicko2_rd_away_before', 'glicko2_vol_home_before',
#        'glicko2_vol_away_before', 'trueskill_home_before',
#        'trueskill_away_before'],
#       dtype='object')

# %%
fbref_df_date_filtered_concat_no_nan__train = fbref_df_date_filtered_concat_no_nan[(fbref_df_date_filtered_concat_no_nan['FTR'].notnull()) & (fbref_df_date_filtered_concat_no_nan['season'] != '2425')]
fbref_df_date_filtered_concat_no_nan__train
# Out:
#         game_id              league season  \
# 0      880e137f  ENG-Premier League   0607
# 1      60c88132         FRA-Ligue 1   0607
# 7      4742f790  ENG-Premier League   0607
# 9      dc45f23c  ENG-Premier League   0607
# 14     36cd8447         ITA-Serie A   0607
# ...         ...                 ...    ...
# 31710  2ee9be16         ITA-Serie A   2324
# 31711  723ffa45      GER-Bundesliga   2324
# 31712  febd4e01         FRA-Ligue 1   2324
# 31713  7f01f697         FRA-Ligue 1   2324
# 31714  ceb127e3         ITA-Serie A   2324
#
#                                       game  \
# 0             2006-09-09 Everton-Liverpool
# 1                  2006-09-09 Nantes-Lille
# 7          2006-09-09 Newcastle Utd-Fulham
# 9      2006-09-09 Manchester Utd-Tottenham
# 14             2006-09-09 Fiorentina-Inter
# ...                                    ...
# 31710               2024-05-26 Empoli-Roma
# 31711         2024-05-27 Düsseldorf-Bochum
# 31712        2024-05-30 Saint-Étienne-Metz
# 31713        2024-06-02 Metz-Saint-Étienne
# 31714       2024-06-02 Atalanta-Fiorentina
#
#                                            round  week  day       date  \
# 0                                           None   4.0  Sat 2006-09-09
# 1                                           None   5.0  Sat 2006-09-09
# 7                                           None   4.0  Sat 2006-09-09
# 9                                           None   4.0  Sat 2006-09-09
# 14                                          None   1.0  Sat 2006-09-09
# ...                                          ...   ...  ...        ...
# 31710                                       None  38.0  Sun 2024-05-26
# 31711  German 1/2 Relegation/Promotion Play-offs   NaN  Mon 2024-05-27
# 31712   French 1/2 Relegation/Promotion Play-off   NaN  Thu 2024-05-30
# 31713   French 1/2 Relegation/Promotion Play-off   NaN  Sun 2024-06-02
# 31714                                       None  29.0  Sun 2024-06-02
#
#            time       home_team  ...  \
# 0          None         Everton  ...
# 1          None          Nantes  ...
# 7          None   Newcastle Utd  ...
# 9          None  Manchester Utd  ...
# 14         None      Fiorentina  ...
# ...         ...             ...  ...
# 31710  20:45:00          Empoli  ...
# 31711  20:30:00      Düsseldorf  ...
# 31712  20:30:00   Saint-Étienne  ...
# 31713  17:00:00            Metz  ...
# 31714  18:00:00        Atalanta  ...
#
#        avg_home_team_goals_season_to_date_before_match  \
# 0                                             0.000000
# 1                                             0.000000
# 7                                             0.000000
# 9                                             0.000000
# 14                                            0.000000
# ...                                                ...
# 31710                                         0.729730
# 31711                                         3.000000
# 31712                                         0.000000
# 31713                                         1.028571
# 31714                                         1.891892
#
#       avg_away_team_goals_season_to_date_before_match  glicko2_home_before  \
# 0                                            0.000000          1500.000000
# 1                                            0.000000          1500.000000
# 7                                            0.000000          1500.000000
# 9                                            0.000000          1500.000000
# 14                                           0.000000          1500.000000
# ...                                               ...                  ...
# 31710                                        1.729730          1451.783789
# 31711                                        1.200000          1467.347180
# 31712                                        1.029412          1500.995626
# 31713                                        2.000000          1426.418607
# 31714                                        1.567568          1605.557956
#
#       glicko2_away_before  glicko2_rd_home_before glicko2_rd_away_before  \
# 0             1500.000000              350.000000             350.000000
# 1             1500.000000              350.000000             350.000000
# 7             1500.000000              350.000000             350.000000
# 9             1500.000000              350.000000             350.000000
# 14            1500.000000              350.000000             350.000000
# ...                   ...                     ...                    ...
# 31710         1613.749022               28.165572              28.315661
# 31711         1445.023712               28.594862              28.662918
# 31712         1428.135762               28.911646              27.119836
# 31713         1502.892889               27.466291              28.865399
# 31714         1543.600966               28.124535              28.477187
#
#       glicko2_vol_home_before glicko2_vol_away_before trueskill_home_before  \
# 0                    0.060000                0.060000              0.000000
# 1                    0.060000                0.060000              0.000000
# 7                    0.060000                0.060000              0.000000
# 9                    0.060000                0.060000              0.000000
# 14                   0.060000                0.060000              0.000000
# ...                       ...                     ...                   ...
# 31710                0.059686                0.059418             21.080298
# 31711                0.059902                0.059850             20.755207
# 31712                0.059508                0.059740             22.420056
# 31713                0.059739                0.059507             21.126454
# 31714                0.059467                0.059383             24.724602
#
#        trueskill_away_before
# 0                   0.000000
# 1                   0.000000
# 7                   0.000000
# 9                   0.000000
# 14                  0.000000
# ...                      ...
# 31710              24.392905
# 31711              20.932579
# 31712              21.203970
# 31713              22.490834
# 31714              23.197665
#
# [28573 rows x 93 columns]

# %%
fbref_df_date_filtered_concat_no_nan__infer = fbref_df_date_filtered_concat_no_nan[fbref_df_date_filtered_concat_no_nan['season'] == '2425']
fbref_df_date_filtered_concat_no_nan__infer
# Out:
#         game_id                      league season  \
# 31715  bd775264  INT-European Championships   2425
# 31716  b996c4de  INT-European Championships   2425
# 31717  c15ec4e7  INT-European Championships   2425
# 31718  4891e62c  INT-European Championships   2425
# 31719  923de563  INT-European Championships   2425
# 31720  94c752b7  INT-European Championships   2425
# 31721  e58cc259  INT-European Championships   2425
# 31722  5bda83ea  INT-European Championships   2425
# 31723  3d8961eb  INT-European Championships   2425
# 31724  67c17ad9  INT-European Championships   2425
# 31725  5e8192b8  INT-European Championships   2425
# 31726  36e9e40e  INT-European Championships   2425
# 31727  5ef87a15  INT-European Championships   2425
# 31728  248233a8  INT-European Championships   2425
# 31729  30406358  INT-European Championships   2425
# 31730  6cfeccb2  INT-European Championships   2425
# 31731  874a95ef  INT-European Championships   2425
# 31732  3f7c6e94  INT-European Championships   2425
# 31733  ad8d106c  INT-European Championships   2425
# 31734  298d4d8f  INT-European Championships   2425
# 31735  73849328  INT-European Championships   2425
# 31736  e0d67eb9  INT-European Championships   2425
# 31737  aab219f9  INT-European Championships   2425
# 31738  5448c54c  INT-European Championships   2425
# 31746   2024-06-25 Netherlands-Austria  Group stage   3.0  Tue 2024-06-25
# 31747       2024-06-26 Czechia-Türkiye  Group stage   3.0  Wed 2024-06-26
# 31748      2024-06-26 Slovakia-Romania  Group stage   3.0  Wed 2024-06-26
# 31749       2024-06-26 Ukraine-Belgium  Group stage   3.0  Wed 2024-06-26
# 31750      2024-06-26 Georgia-Portugal  Group stage   3.0  Wed 2024-06-26
#
#            time    home_team  ...  \
# 31715  21:00:00      Germany  ...
# 31716  18:00:00        Spain  ...
# 31717  15:00:00      Hungary  ...
# 31718  21:00:00        Italy  ...
# 31719  15:00:00       Poland  ...
# 31720  21:00:00       Serbia  ...
# 31721  18:00:00     Slovenia  ...
# 31722  18:00:00      Belgium  ...
# 31723  21:00:00      Austria  ...
# 31724  15:00:00      Romania  ...
# 31725  21:00:00     Portugal  ...
# 31726  18:00:00      Türkiye  ...
# 31727  21:00:00     Scotland  ...
# 31728  18:00:00      Germany  ...
# 31729  15:00:00      Croatia  ...
# 31730  18:00:00      Denmark  ...
# 31731  15:00:00     Slovenia  ...
# 31732  21:00:00        Spain  ...
# 31733  21:00:00  Netherlands  ...
# 31734  18:00:00       Poland  ...
# 31735  15:00:00     Slovakia  ...
# 31736  21:00:00      Belgium  ...
# 31737  15:00:00      Georgia  ...
# 31738  18:00:00      Türkiye  ...
# 31739  21:00:00     Scotland  ...
# 31740  21:00:00  Switzerland  ...
# 31741  21:00:00      Albania  ...
# 31742  21:00:00      Croatia  ...
# 31743  21:00:00      England  ...
# 31744  18:00:00       France  ...
# 31745  21:00:00      Denmark  ...
# 31746  18:00:00  Netherlands  ...
# 31747  21:00:00      Czechia  ...
# 31748  18:00:00     Slovakia  ...
# 31749  18:00:00      Ukraine  ...
# 31750  21:00:00      Georgia  ...
#
#        avg_home_team_goals_season_to_date_before_match  \
# 31715                                              0.0
# 31716                                              0.0
# 31717                                              0.0
# 31718                                              0.0
# 31719                                              0.0
# 31720                                              0.0
# 31721                                              0.0
# 31722                                              0.0
# 31723                                              0.0
# 31724                                              0.0
# 31725                                              0.0
# 31726                                              0.0
# 31727                                              0.0
# 31728                                              0.0
# 31729                                              0.0
# 31730                                              0.0
# 31731                                              0.0
# 31732                                              0.0
# 31733                                              0.0
# 31734                                              0.0
# 31735                                              0.0
# 31736                                              0.0
# 31737                                              0.0
# 31738                                              0.0
# 31739                                              0.0
# 31740                                              0.0
# 31741                                              0.0
# 31742                                              0.0
# 31743                                              0.0
# 31744                                              0.0
# 31745                                              0.0
# 31746                                              0.0
# 31747                                              0.0
# 31748                                              0.0
# 31749                                              0.0
# 31750                                              0.0
#
#       avg_away_team_goals_season_to_date_before_match  glicko2_home_before  \
# 31715                                             0.0          1526.719791
# 31716                                             0.0          1526.232249
# 31717                                             0.0          1498.703488
# 31718                                             0.0          1519.102653
# 31719                                             0.0          1483.375706
# 31720                                             0.0          1472.577393
# 31721                                             0.0          1489.878534
# 31722                                             0.0          1541.754917
# 31723                                             0.0          1485.499373
# 31724                                             0.0          1490.574717
# 31725                                             0.0          1508.521092
# 31726                                             0.0          1467.028333
# 31730                0.059988                0.059975                   0.0
# 31731                0.059998                0.059995                   0.0
# 31732                0.059958                0.059972                   0.0
# 31733                0.059987                0.059974                   0.0
# 31734                0.059975                0.059995                   0.0
# 31735                0.060000                0.059998                   0.0
# 31736                0.059992                0.059993                   0.0
# 31737                0.060000                0.059994                   0.0
# 31738                0.059997                0.059974                   0.0
# 31739                0.059995                0.059986                   0.0
# 31740                0.059976                0.059982                   0.0
# 31741                0.060000                0.059958                   0.0
# 31742                0.059969                0.059972                   0.0
# 31743                0.059975                0.059998                   0.0
# 31744                0.059974                0.059975                   0.0
# 31745                0.059988                0.059995                   0.0
# 31746                0.059987                0.059995                   0.0
# 31747                0.059994                0.059997                   0.0
# 31748                0.060000                0.059993                   0.0
# 31749                0.059998                0.059992                   0.0
# 31750                0.060000                0.059974                   0.0
#
#        trueskill_away_before
# 31715                    0.0
# 31716                    0.0
# 31717                    0.0
# 31718                    0.0
# 31719                    0.0
# 31720                    0.0
# 31721                    0.0
# 31722                    0.0
# 31723                    0.0
# 31724                    0.0
# 31725                    0.0
# 31726                    0.0
# 31727                    0.0
# 31728                    0.0
# 31729                    0.0
# 31730                    0.0
# 31731                    0.0
# 31732                    0.0
# 31733                    0.0
# 31734                    0.0
# 31735                    0.0
# 31736                    0.0
# 31737                    0.0
# 31738                    0.0
# 31739                    0.0
# 31740                    0.0
# 31741                    0.0
# 31742                    0.0
# 31743                    0.0
# 31744                    0.0
# 31745                    0.0
# 31746                    0.0
# 31747                    0.0
# 31748                    0.0
# 31749                    0.0
# 31750                    0.0
#
# [36 rows x 93 columns]

# %%
from sklearn.feature_selection import SelectKBest, f_classif

pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LogisticRegression())
    ])
X_col_sofifa =  ['home_overall', 'home_attack', 
         'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
         'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
         'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
         'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']

Y_col = 'FTR'

X_col = X_col_sofifa + X_col_scores

train_test_split_fn = lambda df : train_test_split_expanding_windows(df, split=5, test_prop=0.2, date_col="date")
result_df_all_splits = False
m = 10
beta = 1

metrics_mean, metrics, _ = train_test(fbref_df_date_filtered_concat_no_nan__train, pipeline, X_col, Y_col, train_test_split_fn, result_df_all_splits, m, beta)
pd.DataFrame({'metrics': metrics_mean.keys(), 'values': metrics_mean.values()})
# Out:
#                metrics    values
# 0             accuracy  0.526958
# 1    weighted_accuracy  0.668501
# 2        accuracy_home  0.594718
# 3        accuracy_draw  0.741530
# 4        accuracy_away  0.717668
# 5           recall_all  1.346776
# 6      weighted_recall  0.526958
# 7    balanced_accuracy  0.448925
# 8          recall_home  0.844371
# 9          recall_draw  0.000000
# 10         recall_away  0.502405
# 11       precision_all  0.350697
# 12  weighted_precision  0.391217
# 13      precision_home  0.528020
# 14      precision_draw  0.000000
# 15      precision_away  0.524071
# 16        f_mesure_all  0.386219
# 17   f_mesure_weighted  0.441550
# 18       f_mesure_home  0.649181
# 19       f_mesure_draw  0.000000
# 20       f_mesure_away  0.509476
# 21            log_loss  0.985650
# 22           loss_home  0.301875
# 23           loss_draw  0.366906
# 24           loss_away  0.316869
# 25                 mse  0.195518
# 26            mse_home  0.215566
# 27            mse_draw  0.190504
# 28            mse_away  0.180483
# 29       classwise_ECE  0.030681
# 30            ECE_home  0.040057
# 31            ECE_draw  0.028403
# 32            ECE_away  0.023583

# %%
from sklearn.feature_selection import SelectKBest, f_classif

pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LogisticRegression())
    ])
X_col_sofifa =  ['home_overall', 'home_attack', 
         'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
         'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
         'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
         'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']


Y_col = 'FTR'

X_col = X_col_sofifa + X_col_scores

pipeline.fit(fbref_df_date_filtered_concat_no_nan__train[X_col], fbref_df_date_filtered_concat_no_nan__train[Y_col])
fbref_df_date_filtered_concat_no_nan__train['pred'] = pipeline.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])
fbref_df_date_filtered_concat_no_nan__train['proba_home_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 2]
fbref_df_date_filtered_concat_no_nan__train['proba_draw'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 1]
fbref_df_date_filtered_concat_no_nan__train['proba_away_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 0]

accucacy = accuracy_fn(fbref_df_date_filtered_concat_no_nan__train, 'FTR', 'pred')[0]
log_loss = log_loss_fn(fbref_df_date_filtered_concat_no_nan__train['FTR'], fbref_df_date_filtered_concat_no_nan__train['proba_home_win'], fbref_df_date_filtered_concat_no_nan__train['proba_draw'], fbref_df_date_filtered_concat_no_nan__train['proba_away_win'])

pd.DataFrame({'metrics': ['accuracy', 'log_loss'], 'values': [accucacy, log_loss]})
# Out:
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3529199212.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['pred'] = pipeline.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3529199212.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['proba_home_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 2]
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3529199212.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['proba_draw'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 1]
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3529199212.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['proba_away_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__train[X_col])[:, 0]
#     metrics    values
# 0  accuracy  0.521996
# 1  log_loss  0.987674

# %%
fbref_df_date_filtered_concat_no_nan__infer[X_col[10:30]]
# Out:
#        home_whole_team_average_age  away_overall  away_attack  away_midfield  \
# 31715                        28.04          76.0         72.0           77.0
# 31716                        26.69          79.0         77.0           82.0
# 31717                        26.19          79.0         77.0           78.0
# 31718                        27.04          73.0         66.0           73.0
# 31719                        26.50          82.0         82.0           82.0
# 31720                        26.46          85.0         87.0           86.0
# 31721                        26.30          79.0         76.0           78.0
# 31722                        26.23          75.0         73.0           76.0
# 31723                        25.87          84.0         86.0           85.0
# 31724                        26.27          77.0         81.0           77.0
# 31725                        27.00          75.0         74.0           75.0
# 31726                        24.09          71.0         75.0           70.0
# 31727                        26.85          79.0         77.0           78.0
# 31728                        28.04          75.0         76.0           71.0
# 31729                        26.46          73.0         66.0           73.0
# 31730                        26.35          85.0         87.0           86.0
# 31731                        26.30          79.0         80.0           80.0
# 31732                        26.69          82.0         82.0           82.0
# 31733                        26.00          84.0         86.0           85.0
# 31734                        26.50          77.0         78.0           78.0
# 31735                        27.96          77.0         81.0           77.0
# 31736                        26.23          72.0         70.0           72.0
# 31737                        26.17          75.0         74.0           75.0
# 31738                        24.09          84.0         85.0           84.0
# 31739                        26.85          75.0         76.0           71.0
# 31740                        26.62          85.0         81.0           85.0
# 31741                        26.78          83.0         83.0           84.0
# 31742                        26.46          82.0         82.0           82.0
# 31743                        25.69          73.0         70.0           73.0
# 31744                        25.65          77.0         79.0           75.0
# 31745                        26.35          79.0         80.0           80.0
# 31746                        26.00          77.0         78.0           78.0
# 31747                        25.62          77.0         79.0           76.0
# 31748                        27.96          72.0         70.0           72.0
# 31749                        26.23          81.0         82.0           81.0
# 31750                        26.17          84.0         85.0           84.0
#
#        away_defence  away_transfer_budget  away_club_worth  \
# 31715          76.0                   0.0              0.0
# 31716          77.0                   0.0              0.0
# 31717          78.0                   0.0              0.0
# 31718          74.0                   0.0              0.0
# 31719          83.0                   0.0              0.0
# 31720          83.0                   0.0              0.0
# 31721          79.0                   0.0              0.0
# 31722          75.0                   0.0              0.0
# 31723          83.0                   0.0              0.0
# 31724          74.0                   0.0              0.0
# 31725          75.0                   0.0              0.0
# 31726          68.0                   0.0              0.0
# 31727          78.0                   0.0              0.0
# 31728          73.0                   0.0              0.0
# 31729          74.0                   0.0              0.0
# 31730          83.0                   0.0              0.0
# 31731          75.0                   0.0              0.0
# 31732          82.0                   0.0              0.0
# 31733          83.0                   0.0              0.0
# 31734          77.0                   0.0              0.0
# 31735          74.0                   0.0              0.0
# 31736          71.0                   0.0              0.0
# 31737          75.0                   0.0              0.0
# 31738          83.0                   0.0              0.0
# 31739          73.0                   0.0              0.0
# 31740          83.0                   0.0              0.0
# 31741          83.0                   0.0              0.0
# 31742          82.0                   0.0              0.0
# 31743          71.0                   0.0              0.0
# 31744          74.0                   0.0              0.0
# 31745          75.0                   0.0              0.0
# 31746          77.0                   0.0              0.0
# 31747          75.0                   0.0              0.0
# 31748          71.0                   0.0              0.0
# 31749          77.0                   0.0              0.0
# 31750          83.0                   0.0              0.0
#
#        away_defence_domestic_prestige  away_international_prestige  \
# 31715                            10.0                          4.0
# 31716                            10.0                          6.0
# 31717                            10.0                          6.0
# 31718                            10.0                          2.0
# 31719                            10.0                          8.0
# 31720                            10.0                          8.0
# 31721                            10.0                          6.0
# 31722                            10.0                          3.0
# 31723                            10.0                         10.0
# 31724                            10.0                          6.0
# 31725                            10.0                          5.0
# 31726                            10.0                          2.0
# 31727                            10.0                          6.0
# 31728                            10.0                          4.0
# 31729                            10.0                          2.0
# 31730                            10.0                          8.0
# 31731                            10.0                          6.0
# 31732                            10.0                          9.0
# 31733                            10.0                         10.0
# 31734                            10.0                          4.0
# 31735                            10.0                          6.0
# 31736                            10.0                          5.0
# 31737                            10.0                          5.0
# 31738                            10.0                          8.0
# 31739                            10.0                          4.0
# 31740                            10.0                         10.0
# 31741                            10.0                          9.0
# 31742                            10.0                          9.0
# 31743                            10.0                          5.0
# 31744                            10.0                          5.0
# 31745                            10.0                          6.0
# 31746                            10.0                          4.0
# 31747                            10.0                          6.0
# 31748                            10.0                          5.0
# 31749                            10.0                          8.0
# 31750                            10.0                          8.0
#
#        away_players  away_starting_xi_average_age  \
# 31715          26.0                         26.73
# 31716          26.0                         27.18
# 31717          26.0                         28.09
# 31718          23.0                         27.09
# 31719          26.0                         26.55
# 31720          26.0                         26.27
# 31721          26.0                         27.27
# 31722          23.0                         29.64
# 31723          26.0                         27.27
# 31724          26.0                         24.27
# 31725          26.0                         25.45
# 31726          23.0                         26.27
# 31727          26.0                         28.09
# 31728          26.0                         26.27
# 31729          23.0                         27.09
# 31730          26.0                         26.27
# 31731          26.0                         26.36
# 31732          26.0                         28.18
# 31733          26.0                         27.27
# 31734          23.0                         25.82
# 31735          26.0                         24.27
# 31736          26.0                         26.45
# 31737          26.0                         25.45
# 31738          26.0                         26.91
# 31739          26.0                         26.27
# 31740          26.0                         27.73
# 31741          26.0                         27.00
# 31742          26.0                         28.18
# 31743          23.0                         26.64
# 31744          26.0                         26.91
# 31745          26.0                         26.36
# 31746          23.0                         25.82
# 31747          23.0                         25.18
# 31748          26.0                         26.45
# 31749          26.0                         27.73
# 31750          26.0                         26.91
#
#        away_whole_team_average_age  home_team_number_of_match_played  \
# 31715                        26.85                               0.0
# 31716                        26.46                               0.0
# 31717                        26.62                               0.0
# 31718                        26.78                               0.0
# 31719                        26.00                               0.0
# 31720                        25.69                               0.0
# 31721                        26.35                               0.0
# 31737          1489.090585              350.000000               28.966534
# 31738          1508.521092               37.187552               28.913849
# 31739          1498.703488               49.860495               33.523677
# 31740          1526.719791               29.327910               27.909337
# 31741          1526.232249              350.000000               28.147176
# 31742          1519.102653               29.021807               29.092133
# 31743          1489.878534               28.374000               59.785389
# 31744          1483.375706               29.078495               29.246638
# 31745          1472.577393               27.845977               49.891746
# 31746          1485.499373               28.332196               34.885691
# 31747          1467.028333               28.966534               37.187552
# 31748          1490.574717              350.000000               36.677593
# 31749          1541.754917               31.867851               28.037093
# 31750          1508.521092              350.000000               28.913849
#
#        glicko2_vol_home_before  glicko2_vol_away_before
# 31715                 0.059982                 0.059995
# 31716                 0.059958                 0.059969
# 31717                 0.059986                 0.059976
# 31718                 0.059972                 0.060000
# 31719                 0.059975                 0.059987
# 31720                 0.059995                 0.059975
# 31721                 0.059998                 0.059988
# 31722                 0.059992                 0.060000
# 31723                 0.059995                 0.059974
# 31724                 0.059993                 0.059998
# 31725                 0.059974                 0.059994
# 31726                 0.059997                 0.060000
# 31727                 0.059995                 0.059976
# 31728                 0.059982                 0.059986
# 31729                 0.059969                 0.060000
# 31730                 0.059988                 0.059975
# 31731                 0.059998                 0.059995
# 31732                 0.059958                 0.059972
# 31733                 0.059987                 0.059974
# 31734                 0.059975                 0.059995
# 31735                 0.060000                 0.059998
# 31736                 0.059992                 0.059993
# 31737                 0.060000                 0.059994
# 31738                 0.059997                 0.059974
# 31739                 0.059995                 0.059986
# 31740                 0.059976                 0.059982
# 31741                 0.060000                 0.059958
# 31742                 0.059969                 0.059972
# 31743                 0.059975                 0.059998
# 31744                 0.059974                 0.059975
# 31745                 0.059988                 0.059995
# 31746                 0.059987                 0.059995
# 31747                 0.059994                 0.059997
# 31748                 0.060000                 0.059993
# 31749                 0.059998                 0.059992
# 31750                 0.060000                 0.059974

# %%
fbref_df_date_filtered_concat_no_nan__infer['pred'] = pipeline.predict(fbref_df_date_filtered_concat_no_nan__infer[X_col])
fbref_df_date_filtered_concat_no_nan__infer['proba_home_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__infer[X_col])[:, 2]
fbref_df_date_filtered_concat_no_nan__infer['proba_draw'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__infer[X_col])[:, 1]
fbref_df_date_filtered_concat_no_nan__infer['proba_away_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__infer[X_col])[:, 0]

fbref_df_date_filtered_concat_no_nan__infer[['date', 'home_team', 'away_team', 'proba_home_win', 'proba_draw', 'proba_away_win', 'pred']]
# Out:
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\1900088215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__infer['pred'] = pipeline.predict(fbref_df_date_filtered_concat_no_nan__infer[X_col])
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\1900088215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__infer['proba_home_win'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__infer[X_col])[:, 2]
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\1900088215.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__infer['proba_draw'] = pipeline.predict_proba(fbref_df_date_filtered_concat_no_nan__infer[X_col])[:, 1]
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel
# 31734        0.405194  -1.0
# 31735        0.333132   1.0
# 31736        0.173606   1.0
# 31737        0.381638  -1.0
# 31738        0.528735  -1.0
# 31739        0.313859   1.0
# 31740        0.476807  -1.0
# 31741        0.512049  -1.0
# 31742        0.398386  -1.0
# 31743        0.140871   1.0
# 31744        0.187139   1.0
# 31745        0.335078   1.0
# 31746        0.246358   1.0
# 31747        0.374116  -1.0
# 31748        0.219673   1.0
# 31749        0.455965  -1.0
# 31750        0.583715  -1.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Suppose the target columns are 'home_goals' and 'away_goals'
Y_col_home = 'home_g'
Y_col_away = 'away_g'

X_col_sofifa =  ['home_overall', 'home_attack', 
                 'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
                 'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
                 'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
                 'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']

X_col = X_col_sofifa + X_col_scores

# Define the pipeline
pipeline_home = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

pipeline_away = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

# Fit the models
pipeline_home.fit(fbref_df_date_filtered_concat_no_nan__train[X_col], fbref_df_date_filtered_concat_no_nan__train[Y_col_home])
pipeline_away.fit(fbref_df_date_filtered_concat_no_nan__train[X_col], fbref_df_date_filtered_concat_no_nan__train[Y_col_away])

# Predict goals
fbref_df_date_filtered_concat_no_nan__train['pred_home_goals'] = pipeline_home.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])
fbref_df_date_filtered_concat_no_nan__train['pred_away_goals'] = pipeline_away.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])

# Calculate metrics
mse_home = mean_squared_error(fbref_df_date_filtered_concat_no_nan__train[Y_col_home], fbref_df_date_filtered_concat_no_nan__train['pred_home_goals'])
mse_away = mean_squared_error(fbref_df_date_filtered_concat_no_nan__train[Y_col_away], fbref_df_date_filtered_concat_no_nan__train['pred_away_goals'])
r2_home = r2_score(fbref_df_date_filtered_concat_no_nan__train[Y_col_home], fbref_df_date_filtered_concat_no_nan__train['pred_home_goals'])
r2_away = r2_score(fbref_df_date_filtered_concat_no_nan__train[Y_col_away], fbref_df_date_filtered_concat_no_nan__train['pred_away_goals'])

# Display metrics
pd.DataFrame({
    'metrics': ['mse_home', 'mse_away', 'r2_home', 'r2_away'],
    'values': [mse_home, mse_away, r2_home, r2_away]
})
# Out:
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3017695438.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['pred_home_goals'] = pipeline_home.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel_26548\3017695438.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_df_date_filtered_concat_no_nan__train['pred_away_goals'] = pipeline_away.predict(fbref_df_date_filtered_concat_no_nan__train[X_col])
#     metrics    values
# 0  mse_home  1.485994
# 1  mse_away  1.212352
# 2   r2_home  0.122230
# 3   r2_away  0.094871

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Suppose the target columns are 'home_goals' and 'away_goals'
Y_col_home = 'home_g'
Y_col_away = 'away_g'

X_col_sofifa =  ['home_overall', 'home_attack', 
                 'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
                 'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
                 'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
                 'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']

X_col = X_col_sofifa + X_col_scores

# Define the pipeline
pipeline_home = Pipeline([
        ('scaler', StandardScaler()),
        ('model', RandomForestClassifier())
    ])

pipeline_away = Pipeline([
        ('scaler', StandardScaler()),
        ('model', RandomForestClassifier())
    ])

split = train_test_split_expanding_windows(fbref_df_date_filtered_concat_no_nan__train, split=5, test_prop=0.2, date_col="date")

mse_home = []
mse_away = []
r2_home = []
r2_away = []

for train, test in split:
    # Fit the models
    pipeline_home.fit(train[X_col], train[Y_col_home])
    pipeline_away.fit(train[X_col], train[Y_col_away])

    # Predict goals
    test['pred_home_goals'] = pipeline_home.predict(test[X_col])
    test['pred_away_goals'] = pipeline_away.predict(test[X_col])

    # Calculate metrics
    mse_home.append(mean_squared_error(test[Y_col_home], test['pred_home_goals']))
    mse_away.append(mean_squared_error(test[Y_col_away], test['pred_away_goals']))
    r2_home.append(r2_score(test[Y_col_home], test['pred_home_goals']))
    r2_away.append(r2_score(test[Y_col_away], test['pred_away_goals']))

# Display metrics
pd.DataFrame({
    'metrics': ['mse_home', 'mse_away', 'r2_home', 'r2_away'],
    'values': [np.mean(mse_home), np.mean(mse_away), np.mean(r2_home), np.mean(r2_away)]
})
# Out:
#     metrics    values
# 0  mse_home  1.922222
# 1  mse_away  1.676503
# 2   r2_home -0.164873
# 3   r2_away -0.279170

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Suppose the target columns are 'home_goals' and 'away_goals'
Y_col_home = 'home_g'
Y_col_away = 'away_g'

X_col_sofifa =  ['home_overall', 'home_attack', 
                 'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
                 'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
                 'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
                 'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']

X_col = X_col_sofifa + X_col_scores

# Define the pipeline
pipeline_home = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

pipeline_away = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

split = train_test_split_expanding_windows(fbref_df_date_filtered_concat_no_nan__train, split=5, test_prop=0.2, date_col="date")

mse_home = []
mse_away = []
r2_home = []
r2_away = []

for train, test in split:
    # Fit the models
    pipeline_home.fit(train[X_col], train[Y_col_home])
    pipeline_away.fit(train[X_col], train[Y_col_away])

    # Predict goals
    test['pred_home_goals'] = pipeline_home.predict(test[X_col])
    test['pred_away_goals'] = pipeline_away.predict(test[X_col])

    # Calculate metrics
    mse_home.append(mean_squared_error(test[Y_col_home], test['pred_home_goals']))
    mse_away.append(mean_squared_error(test[Y_col_away], test['pred_away_goals']))
    r2_home.append(r2_score(test[Y_col_home], test['pred_home_goals']))
    r2_away.append(r2_score(test[Y_col_away], test['pred_away_goals']))

# Display metrics
pd.DataFrame({
    'metrics': ['mse_home', 'mse_away', 'r2_home', 'r2_away'],
    'values': [np.mean(mse_home), np.mean(mse_away), np.mean(r2_home), np.mean(r2_away)]
})
# Out:
#     metrics    values
# 0  mse_home  1.435947
# 1  mse_away  1.189226
# 2   r2_home  0.129387
# 3   r2_away  0.092697

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Suppose the target columns are 'home_goals' and 'away_goals'
Y_col_home = 'home_g'
Y_col_away = 'away_g'

X_col_sofifa =  ['home_overall', 'home_attack', 
                 'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
                 'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
                 'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
                 'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'glicko2_home_before', 'glicko2_away_before'
]

X_col = X_col_sofifa + X_col_scores

# Define the pipeline
pipeline_home = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

pipeline_away = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LinearRegression())
    ])

split = train_test_split_expanding_windows(fbref_df_date_filtered_concat_no_nan__train, split=5, test_prop=0.2, date_col="date")

mse_home = []
mse_away = []
r2_home = []
r2_away = []

for train, test in split:
    # Fit the models
    pipeline_home.fit(train[X_col], train[Y_col_home])
    pipeline_away.fit(train[X_col], train[Y_col_away])

    # Predict goals
    test['pred_home_goals'] = pipeline_home.predict(test[X_col])
    test['pred_away_goals'] = pipeline_away.predict(test[X_col])

    # Calculate metrics
    mse_home.append(mean_squared_error(test[Y_col_home], test['pred_home_goals']))
    mse_away.append(mean_squared_error(test[Y_col_away], test['pred_away_goals']))
    r2_home.append(r2_score(test[Y_col_home], test['pred_home_goals']))
    r2_away.append(r2_score(test[Y_col_away], test['pred_away_goals']))

# Display metrics
pd.DataFrame({
    'metrics': ['mse_home', 'mse_away', 'r2_home', 'r2_away'],
    'values': [np.mean(mse_home), np.mean(mse_away), np.mean(r2_home), np.mean(r2_away)]
})
# Out:
#     metrics    values
# 0  mse_home  1.438988
# 1  mse_away  1.191142
# 2   r2_home  0.127564
# 3   r2_away  0.091075

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
#adaboost
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Suppose the target columns are 'home_goals' and 'away_goals'
Y_col_home = 'home_g'
Y_col_away = 'away_g'

X_col_sofifa =  ['home_overall', 'home_attack', 
                 'home_midfield', 'home_defence', 'home_transfer_budget', 'home_club_worth', 'home_defence_domestic_prestige', 'home_international_prestige', 
                 'home_players', 'home_starting_xi_average_age', 'home_whole_team_average_age', 'away_overall', 'away_attack', 'away_midfield', 'away_defence', 
                 'away_transfer_budget', 'away_club_worth', 'away_defence_domestic_prestige', 'away_international_prestige', 'away_players', 
                 'away_starting_xi_average_age', 'away_whole_team_average_age']

X_col_scores = [
       'home_team_number_of_match_played', 'away_team_number_of_match_played',
       'glicko2_home_before', 'glicko2_away_before', 'glicko2_rd_home_before',
       'glicko2_rd_away_before', 'glicko2_vol_home_before',
       'glicko2_vol_away_before', 'trueskill_home_before',
       'trueskill_away_before']

X_col = X_col_sofifa + X_col_scores

# Define the pipeline
pipeline_home = Pipeline([
        ('scaler', StandardScaler()),
        ('model', AdaBoostClassifier())
    ])

pipeline_away = Pipeline([
        ('scaler', StandardScaler()),
        ('model', AdaBoostClassifier())
    ])

split = train_test_split_expanding_windows(fbref_df_date_filtered_concat_no_nan__train, split=5, test_prop=0.2, date_col="date")

mse_home = []
mse_away = []
r2_home = []
r2_away = []

for train, test in split:
    # Fit the models
    pipeline_home.fit(train[X_col], train[Y_col_home])
    pipeline_away.fit(train[X_col], train[Y_col_away])

    # Predict goals
    test['pred_home_goals'] = pipeline_home.predict(test[X_col])
    test['pred_away_goals'] = pipeline_away.predict(test[X_col])

    # Calculate metrics
    mse_home.append(mean_squared_error(test[Y_col_home], test['pred_home_goals']))
    mse_away.append(mean_squared_error(test[Y_col_away], test['pred_away_goals']))
    r2_home.append(r2_score(test[Y_col_home], test['pred_home_goals']))
    r2_away.append(r2_score(test[Y_col_away], test['pred_away_goals']))

# Display metrics
pd.DataFrame({
    'metrics': ['mse_home', 'mse_away', 'r2_home', 'r2_away'],
    'values': [np.mean(mse_home), np.mean(mse_away), np.mean(r2_home), np.mean(r2_away)]
})
# Out:
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 50
#      47 for train, test in split:
#      48     # Fit the models
#      49     pipeline_home.fit(train[X_col], train[Y_col_home])
# ---> 50     pipeline_away.fit(train[X_col], train[Y_col_away])
#      52     # Predict goals
#      53     test['pred_home_goals'] = pipeline_home.predict(test[X_col])
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\pipeline.py:475, in Pipeline.fit(self, X, y, **params)
#     473     if self._final_estimator != "passthrough":
#     474         last_step_params = routed_params[self.steps[-1][0]]
# --> 475         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     477 return self
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:169, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     166 sample_weight[zero_weight_mask] = 0.0
#     168 # Boosting step
# --> 169 sample_weight, estimator_weight, estimator_error = self._boost(
#     170     iboost, X, y, sample_weight, random_state
#     171 )
#     173 # Early termination
#     174 if sample_weight is None:
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:586, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     547 """Implement a single boost.
#     548
#     549 Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     583     If None then boosting has terminated early.
#     584 """
#     585 if self.algorithm == "SAMME.R":
# --> 586     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     588 else:  # elif self.algorithm == "SAMME":
#     589     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\ensemble\_weight_boosting.py:599, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     595 estimator = self._make_estimator(random_state=random_state)
#     597 estimator.fit(X, y, sample_weight=sample_weight)
# --> 599 y_predict_proba = estimator.predict_proba(X)
#     601 if iboost == 0:
#     602     self.classes_ = getattr(estimator, "classes_", None)
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\tree\_classes.py:1042, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#    1018 """Predict class probabilities of the input samples X.
#    1019
#    1020 The predicted class probability is the fraction of samples of the same
#    (...)
#    1039     classes corresponds to that in the attribute :term:`classes_`.
#    1040 """
#    1041 check_is_fitted(self)
# -> 1042 X = self._validate_X_predict(X, check_input)
#    1043 proba = self.tree_.predict(X)
#    1045 if self.n_outputs_ == 1:
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# --> 489 X = self._validate_data(
#     490     X,
#     491     dtype=DTYPE,
#     492     accept_sparse="csr",
#     493     reset=False,
#     494     force_all_finite=force_all_finite,
#     495 )
#     496 if issparse(X) and (
#     497     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     498 ):
#     499     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\utils\validation.py:997, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     995         array = xp.astype(array, dtype, copy=False)
#     996     else:
# --> 997         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     998 except ComplexWarning as complex_warning:
#     999     raise ValueError(
#    1000         "Complex data not supported\n{}\n".format(array)
#    1001     ) from complex_warning
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\sklearn\utils\_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# KeyboardInterrupt:

# %%
fbref_df_date_filtered_concat_no_nan__infer["pred_home_goals"] = pipeline_home.predict(fbref_df_date_filtered_concat_no_nan__infer[X_col])
fbref_df_date_filtered_concat_no_nan__infer["pred_away_goals"] = pipeline_away.predict(fbref_df_date_filtered_concat_no_nan__infer[X_col])

fbref_df_date_filtered_concat_no_nan__infer[['date', 'home_team', 'away_team', 'proba_home_win', 'proba_draw', 'proba_away_win', 'pred', 'pred_home_goals', 'pred_away_goals']]
# Out:
# C:\Users\jdelavande\AppData\Local\Temp\ipykernel
# 31717        0.425496  -1.0         0.952899         1.321227
# 31718        0.282665   1.0         1.383499         0.915947
# 31719        0.541114  -1.0         0.903779         1.602924
# 31720        0.538238  -1.0         0.993241         1.651812
# 31721        0.436904  -1.0         0.830808         1.287112
# 31722        0.322824   1.0         1.440901         1.075845
# 31723        0.504681  -1.0         0.925290         1.523602
# 31724        0.462721  -1.0         0.867528         1.414744
# 31725        0.194107   1.0         1.702290         0.933775
# 31726        0.370345   1.0         1.269110         1.177833
# 31727        0.394628  -1.0         0.904324         1.228675
# 31728        0.158862   1.0         1.762816         0.871445
# 31729        0.331950   1.0         1.277160         1.006654
# 31730        0.516362  -1.0         0.848682         1.560400
# 31731        0.441018  -1.0         0.887401         1.344620
# 31732        0.313610   1.0         1.404380         1.199023
# 31733        0.374106   1.0         1.283401         1.331428
# 31734        0.405194  -1.0         1.082834         1.332756
# 31735        0.333132   1.0         1.243124         1.126710
# 31736        0.173606   1.0         1.807758         0.868605
# 31737        0.381638  -1.0         1.168164         1.156158
# 31738        0.528735  -1.0         0.932199         1.570504
# 31739        0.313859   1.0         1.090356         1.106121
# 31740        0.476807  -1.0         0.993403         1.445752
# 31741        0.512049  -1.0         0.752059         1.359301
# 31742        0.398386  -1.0         1.189692         1.336558
# 31743        0.140871   1.0         1.938787         0.773096
# 31744        0.187139   1.0         1.750390         0.954747
# 31745        0.335078   1.0         1.165782         1.183666
# 31746        0.246358   1.0         1.463969         1.027223
# 31747        0.374116  -1.0         1.018446         1.238470
# 31748        0.219673   1.0         1.405853         0.788193
# 31749        0.455965  -1.0         1.106375         1.487471
# 31750        0.583715  -1.0         0.829356         1.559232

# %%
fbref_df_date_filtered_concat_no_nan__infer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 31715 to 31750
# Data columns (total 99 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   game_id                                          10 non-null     object
#  1   league                                           28 non-null     object
#  2   season                                           28 non-null     object
#  3   game                                             28 non-null     object
#  4   round                                            28 non-null     object
#  5   week                                             28 non-null     float64
#  6   day                                              28 non-null     object
#  7   date                                             28 non-null     datetime64[ns]
#  8   time                                             28 non-null     object
#  9   home_team                                        28 non-null     object
#  10  home_xg                                          10 non-null     float64
#  11  score                                            10 non-null     object
#  12  away_xg                                          10 non-null     float64
#  13  away_team                                        28 non-null     object
#  14  attendance                                       9 non-null      float64
#  15  venue                                            28 non-null     object
#  16  referee                                          10 non-null     object
#  17  match_report                                     10 non-null     object
#  18  notes                                            0 non-null      object
#  19  index                                            28 non-null     int64
#  20  away_g                                           10 non-null     float64
#  21  home_g                                           10 non-null     float64
#  22  away_sat                                         0 non-null      float64
#  23  home_sat                                         0 non-null      float64
#  24  home_league                                      28 non-null     object
#  25  home_overall                                     28 non-null     float64
#  26  home_attack                                      28 non-null     float64
#  27  home_midfield                                    28 non-null     float64
#  28  home_defence                                     28 non-null     float64
#  29  home_transfer_budget                             28 non-null     float64
#  30  home_club_worth                                  28 non-null     float64
#  31  home_build_up_speed                              28 non-null     object
#  32  home_build_up_dribbling                          28 non-null     object
#  33  home_build_up_passing                            28 non-null     object
#  34  home_build_up_positioning                        28 non-null     object
#  35  home_chance_creation_crossing                    28 non-null     object
#  36  home_chance_creation_passing                     28 non-null     object
#  37  home_chance_creation_shooting                    28 non-null     object
#  38  home_chance_creation_positioning                 28 non-null     object
#  39  home_defence_aggression                          28 non-null     object
#  40  home_defence_pressure                            28 non-null     object
#  41  home_defence_team_width                          28 non-null     object
#  42  home_defence_defender_line                       28 non-null     object
#  43  home_defence_domestic_prestige                   28 non-null     float64
#  44  home_international_prestige                      28 non-null     float64
#  45  home_players                                     28 non-null     float64
#  46  home_starting_xi_average_age                     28 non-null     float64
#  47  home_whole_team_average_age                      28 non-null     float64
#  48  home_fifa_edition                                28 non-null     object
#  49  home_update                                      28 non-null     datetime64[ns]
#  50  away_league                                      28 non-null     object
#  51  away_overall                                     28 non-null     float64
#  52  away_attack                                      28 non-null     float64
#  53  away_midfield                                    28 non-null     float64
#  54  away_defence                                     28 non-null     float64
#  55  away_transfer_budget                             28 non-null     float64
#  56  away_club_worth                                  28 non-null     float64
#  57  away_build_up_speed                              28 non-null     object
#  58  away_build_up_dribbling                          28 non-null     object
#  59  away_build_up_passing                            28 non-null     object
#  60  away_build_up_positioning                        28 non-null     object
#  61  away_chance_creation_crossing                    28 non-null     object
#  62  away_chance_creation_passing                     28 non-null     object
#  63  away_chance_creation_shooting                    28 non-null     object
#  64  away_chance_creation_positioning                 28 non-null     object
#  65  away_defence_aggression                          28 non-null     object
#  66  away_defence_pressure                            28 non-null     object
#  67  away_defence_team_width                          28 non-null     object
#  68  away_defence_defender_line                       28 non-null     object
#  69  away_defence_domestic_prestige                   28 non-null     float64
#  70  away_international_prestige                      28 non-null     float64
#  71  away_players                                     28 non-null     float64
#  72  away_starting_xi_average_age                     28 non-null     float64
#  73  away_whole_team_average_age                      28 non-null     float64
#  74  away_fifa_edition                                28 non-null     object
#  75  away_update                                      28 non-null     datetime64[ns]
#  76  FTR                                              10 non-null     float64
#  77  elo_home_before                                  22 non-null     float64
#  78  elo_away_before                                  22 non-null     float64
#  79  home_team_goals_season_to_date_before_match      22 non-null     float64
#  80  away_team_goals_season_to_date_before_match      22 non-null     float64
#  81  home_team_number_of_match_played                 28 non-null     float64
#  82  away_team_number_of_match_played                 28 non-null     float64
#  83  avg_home_team_goals_season_to_date_before_match  22 non-null     float64
#  84  avg_away_team_goals_season_to_date_before_match  22 non-null     float64
#  85  glicko2_home_before                              28 non-null     float64
#  86  glicko2_away_before                              28 non-null     float64
#  87  glicko2_rd_home_before                           28 non-null     float64
#  88  glicko2_rd_away_before                           28 non-null     float64
#  89  glicko2_vol_home_before                          28 non-null     float64
#  90  glicko2_vol_away_before                          28 non-null     float64
#  91  trueskill_home_before                            28 non-null     float64
#  92  trueskill_away_before                            28 non-null     float64
#  93  pred                                             28 non-null     float64
#  94  proba_home_win                                   28 non-null     float64
#  95  proba_draw                                       28 non-null     float64
#  96  proba_away_win                                   28 non-null     float64
#  97  pred_home_goals                                  28 non-null     float64
#  98  pred_away_goals                                  28 non-null     float64
# dtypes: datetime64[ns](3), float64(53), int64(1), object(42)
# memory usage: 21.9+ KB
