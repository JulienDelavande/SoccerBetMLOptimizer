# %%
import soccerdata as sd
from sqlalchemy import create_engine, text
import pandas as pd
from dotenv import load_dotenv
import os
from psycopg2 import sql, connect

# %%
load_dotenv()
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')

connection_url = f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'
engine = create_engine(connection_url)

# %%
with engine.connect() as connection:
    query = text('SELECT * FROM matches_euro')
    matches = pd.read_sql(query, connection)

matches
# Out:
#       game_id                      league season  \
# 0    d0cc54df  INT-European Championships   0001
# 1    acf38877  INT-European Championships   0001
# 2    4b680532  INT-European Championships   0001
# 3    6027ced9  INT-European Championships   0001
# 4    afcab359  INT-European Championships   0001
# ..        ...                         ...    ...
# 257      None  INT-European Championships   2425
# 258      None  INT-European Championships   2425
# 259      None  INT-European Championships   2425
# 260      None  INT-European Championships   2425
# 261      None  INT-European Championships   2425
#
#                                game        round  week  day        date  \
# 0         2000-06-10 Belgium-Sweden  Group stage   1.0  Sat  2000-06-10
# 1         2000-06-11 France-Denmark  Group stage   1.0  Sun  2000-06-11
# 2    2000-06-11 Netherlands-Czechia  Group stage   1.0  Sun  2000-06-11
# 3          2000-06-11 Türkiye-Italy  Group stage   1.0  Sun  2000-06-11
# 4        2000-06-12 Germany-Romania  Group stage   1.0  Mon  2000-06-12
# ..                              ...          ...   ...  ...         ...
# 257  2024-06-25 Netherlands-Austria  Group stage   3.0  Tue  2024-06-25
# 258      2024-06-26 Czechia-Türkiye  Group stage   3.0  Wed  2024-06-26
# 259     2024-06-26 Georgia-Portugal  Group stage   3.0  Wed  2024-06-26
# 260     2024-06-26 Slovakia-Romania  Group stage   3.0  Wed  2024-06-26
# 261      2024-06-26 Ukraine-Belgium  Group stage   3.0  Wed  2024-06-26
#
#          time    home_team  ...  away_xg away_team  attendance  \
# 0    20:45:00      Belgium  ...      NaN    Sweden     46700.0
# 1    18:00:00       France  ...      NaN   Denmark     28100.0
# 2    20:45:00  Netherlands  ...      NaN   Czechia     50800.0
# 3    14:30:00      Türkiye  ...      NaN     Italy     22500.0
# 4    18:00:00      Germany  ...      NaN   Romania     28500.0
# ..        ...          ...  ...      ...       ...         ...
# 257  18:00:00  Netherlands  ...      NaN   Austria         NaN
# 258  21:00:00      Czechia  ...      NaN   Türkiye         NaN
# 259  21:00:00      Georgia  ...      NaN  Portugal         NaN
# 260  18:00:00     Slovakia  ...      NaN   Romania         NaN
# 261  18:00:00      Ukraine  ...      NaN   Belgium         NaN
#
#                       venue             referee  \
# 0        Stade Roi Baudouin         Markus Merk
# 1        Jan Breydelstadion        Günter Benkö
# 2        Johan Cruyff ArenA   Pierluigi Collina
# 3                 GelreDome         Hugh Dallas
# 4    Stade Maurice Dufrasne  Kim Milton Nielsen
# ..                      ...                 ...
# 257   Olympiastadion Berlin                None
# 258        Volksparkstadion                None
# 259           Veltins-Arena                None
# 260      Deutsche Bank Park                None
# 261                MHPArena                None
#
#                                           match_report notes     index away_g  \
# 0    /en/matches/d0cc54df/Belgium-Sweden-June-10-20...  None   4640472    1.0
# 1    /en/matches/acf38877/France-Denmark-June-11-20...  None  15909458    0.0
# 2    /en/matches/4b680532/Netherlands-Czechia-June-...  None  13857731    0.0
# 3    /en/matches/6027ced9/Turkiye-Italy-June-11-200...  None   2727014    2.0
# 4    /en/matches/afcab359/Germany-Romania-June-12-2...  None  11856579    1.0
# ..                                                 ...   ...       ...    ...
# 257                                               None  None  12042657    NaN
# 258                                               None  None   2598241    NaN
# 259                                               None  None  10115670    NaN
# 260                                               None  None  10264785    NaN
# 261                                               None  None    729627    NaN
#
#      home_g
# 0       2.0
# 1       3.0
# 2       1.0
# 3       1.0
# 4       1.0
# ..      ...
# 257     NaN
# 258     NaN
# 259     NaN
# 260     NaN
# 261     NaN
#
# [262 rows x 22 columns]

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       226 non-null    object
#  1   league        262 non-null    object
#  2   season        262 non-null    object
#  3   game          262 non-null    object
#  4   round         262 non-null    object
#  5   week          204 non-null    float64
#  6   day           262 non-null    object
#  7   date          262 non-null    object
#  8   time          262 non-null    object
#  9   home_team     262 non-null    object
#  10  home_xg       51 non-null     float64
#  11  score         226 non-null    object
#  12  away_xg       51 non-null     float64
#  13  away_team     262 non-null    object
#  14  attendance    226 non-null    float64
#  15  venue         262 non-null    object
#  16  referee       226 non-null    object
#  17  match_report  226 non-null    object
#  18  notes         23 non-null     object
#  19  index         262 non-null    int64
#  20  away_g        212 non-null    float64
#  21  home_g        212 non-null    float64
# dtypes: float64(6), int64(1), object(15)
# memory usage: 45.2+ KB

# %%
with engine.connect() as connection:
    query = text('SELECT * FROM matches_big5')
    big5 = pd.read_sql(query, connection)

big5
# Out:
#           index   game_id              league season  \
# 0        905822  d9b84fe5  ENG-Premier League   0001
# 1       8826649  7c440c56  ENG-Premier League   0001
# 2       6981257  812d0818  ENG-Premier League   0001
# 3       5772836  b584dafa  ENG-Premier League   0001
# 4       5781709  12b9d2dd  ENG-Premier League   0001
# ...         ...       ...                 ...    ...
# 85809   4524297  55fb12de         ITA-Serie A   9900
# 85810   5376366  58705435         ITA-Serie A   9900
# 85811  13462727  709e9960         ITA-Serie A   9900
# 85812  11508820  fa21656c         ITA-Serie A   9900
# 85813  13182815  c31ad23b         ITA-Serie A   9900
#
#                                           game round  week  day        date  \
# 0      2000-08-19 Charlton Ath-Manchester City  None   1.0  Sat  2000-08-19
# 1                  2000-08-19 Chelsea-West Ham  None   1.0  Sat  2000-08-19
# 2       2000-08-19 Coventry City-Middlesbrough  None   1.0  Sat  2000-08-19
# 3          2000-08-19 Derby County-Southampton  None   1.0  Sat  2000-08-19
# 4              2000-08-19 Leeds United-Everton  None   1.0  Sat  2000-08-19
# ...                                        ...   ...   ...  ...         ...
# 85809                 2000-05-14 Lazio-Reggina  None  34.0  Sun  2000-05-14
# 85810                 2000-05-14 Milan-Udinese  None  34.0  Sun  2000-05-14
# 85811                   2000-05-14 Parma-Lecce  None  34.0  Sun  2000-05-14
# 85812              2000-05-14 Perugia-Juventus  None  34.0  Sun  2000-05-14
# 85813               2000-05-14 Torino-Piacenza  None  34.0  Sun  2000-05-14
#
#        time  ...        away_team  attendance            venue  \
# 0      None  ...  Manchester City     20043.0       The Valley
# 1      None  ...         West Ham     34914.0  Stamford Bridge
# 2      None  ...    Middlesbrough     20624.0   Highfield Road
# 3      None  ...      Southampton     27223.0       Pride Park
# 4      None  ...          Everton     40010.0      Elland Road
# ...     ...  ...              ...         ...              ...
# 85809  None  ...          Reggina         NaN             None
# 85810  None  ...          Udinese         NaN             None
# 85811  None  ...            Lecce         NaN             None
# 85812  None  ...         Juventus         NaN             None
# 85813  None  ...         Piacenza         NaN             None
#
#                   referee                                       match_report  \
# 0              Rob Harris  /en/matches/d9b84fe5/Charlton-Athletic-Manches...
# 1           Graham Barber  /en/matches/7c440c56/Chelsea-West-Ham-United-A...
# 2            Barry Knight  /en/matches/812d0818/Coventry-City-Middlesbrou...
# 3             Andy D'Urso  /en/matches/b584dafa/Derby-County-Southampton-...
# 4        Dermot Gallagher  /en/matches/12b9d2dd/Leeds-United-Everton-Augu...
# ...                   ...                                                ...
# 85809   Gennaro Borriello  /en/matches/55fb12de/Lazio-Reggina-May-14-2000...
# 85810     Graziano Cesari  /en/matches/58705435/Milan-Udinese-May-14-2000...
# 85811  Pasquale Rodomonti  /en/matches/709e9960/Parma-Lecce-May-14-2000-S...
# 85812   Pierluigi Collina  /en/matches/fa21656c/Perugia-Juventus-May-14-2...
# 85813     Stefano Cassarà  /en/matches/c31ad23b/Torino-Piacenza-May-14-20...
#
#        notes away_g home_g away_sat home_sat
# 0       None    0.0    4.0      NaN      NaN
# 1       None    2.0    4.0      NaN      NaN
# 2       None    3.0    1.0      NaN      NaN
# 3       None    2.0    2.0      NaN      NaN
# 4       None    0.0    2.0      NaN      NaN
# ...      ...    ...    ...      ...      ...
# 85809   None    0.0    3.0      NaN      NaN
# 85810   None    0.0    4.0      NaN      NaN
# 85811   None    1.0    4.0      NaN      NaN
# 85812   None    0.0    1.0      NaN      NaN
# 85813   None    1.0    2.0      NaN      NaN
#
# [85814 rows x 24 columns]

# %%
big5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85814 entries, 0 to 85813
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         85814 non-null  int64
#  1   game_id       85814 non-null  object
#  2   league        85814 non-null  object
#  3   season        85814 non-null  object
#  4   game          85814 non-null  object
#  5   round         5672 non-null   object
#  6   week          85781 non-null  float64
#  7   day           85814 non-null  object
#  8   date          85814 non-null  object
#  9   time          18114 non-null  object
#  10  home_team     85814 non-null  object
#  11  home_xg       12582 non-null  float64
#  12  score         85713 non-null  object
#  13  away_xg       12582 non-null  float64
#  14  away_team     85814 non-null  object
#  15  attendance    23965 non-null  float64
#  16  venue         43586 non-null  object
#  17  referee       60187 non-null  object
#  18  match_report  85814 non-null  object
#  19  notes         146 non-null    object
#  20  away_g        85713 non-null  float64
#  21  home_g        85713 non-null  float64
#  22  away_sat      2 non-null      float64
#  23  home_sat      2 non-null      float64
# dtypes: float64(8), int64(1), object(15)
# memory usage: 15.7+ MB
