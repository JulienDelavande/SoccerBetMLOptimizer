# %%
import numpy as np
from scipy.optimize import minimize

# Données d'exemple
M = 5  # Nombre d'événements
N = 3  # Nombre d'issues par événement

# Cotes et probabilités estimées pour chaque issue de chaque événement
o = np.random.rand(M, N) * 5  # Cotes aléatoires entre 1 et 5
r = np.random.rand(M, N)  # Probabilités aléatoires entre 0 et 1
r /= r.sum(axis=1, keepdims=True)  # Normaliser pour que la somme des probabilités pour chaque événement soit 1

# Fonction objectif à maximiser
def objectif(f):
    f = f.reshape(M, N)
    return -np.sum(f * (o * r - 1))



print(f'o = {o}')
print(f'r = {r}')

# Contraintes
constraints = []

# Contrainte : somme des fractions de la bankroll <= 1 pour chaque événement
constraints.append({'type': 'ineq', 'fun': lambda f : 1 - np.sum(f.reshape(M, N))})

# Contrainte : non-négativité
bounds = [(0, 1) for _ in range(M * N)]

# Solution initiale (répartition uniforme)
f0 = np.ones(M * N) / (M * N)

# Résolution de l'optimisation
result = minimize(objectif, f0, constraints=constraints, bounds=bounds)

# Résultats
if result.success:
    f_optimal = result.x.reshape(M, N)
    print("Répartition optimale de la bankroll:")
    print(f_optimal)
else:
    print("L'optimisation a échoué:", result.message)
# Out:
# o = [[0.13613104 1.41260384 3.46993996]
#  [4.17353184 4.37799561 2.16455832]
#  [3.2781791  0.62008532 3.35358614]
#  [4.78759512 2.01632516 1.79051922]
#  [2.49272923 1.13354585 2.75364867]]
# r = [[0.37800839 0.28666093 0.33533067]
#  [0.31976316 0.2672374  0.41299943]
#  [0.29162635 0.19138492 0.51698873]
#  [0.1838297  0.02728253 0.78888777]
#  [0.01740006 0.51015155 0.47244839]]
# Répartition optimale de la bankroll:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [3.29892962e-15 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.49400542e-16]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00]]

# %%
import requests
sport = 'Soccer'
apiKey = API_KEY
regions = 'eu'
markets = 'h2h'
url = f'https://api.the-odds-api.com/v4/sports/{sport}/odds/?apiKey={apiKey}&regions={regions}&markets={markets}'

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# [{'id': '51906a682c32df1067d2b7daaf5a35a5',
#   'sport_key': 'soccer_uefa_europa_conference_league',
#   'sport_title': 'UEFA Europa Conference League',
#   'commence_time': '2024-07-24T15:00:00Z',
#   'home_team': 'FC Struga',
#   'away_team': 'FC Pyunik',
#   'bookmakers': [{'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:43Z',
#       'outcomes': [{'name': 'FC Pyunik', 'price': 3.12},
#        {'name': 'FC Struga', 'price': 2.37},
#        {'name': 'Draw', 'price': 3.1}]}]},
#    {'key': 'williamhill',
#     'title': 'William Hill',
#     'last_update': '2024-07-24T14:03:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:44Z',
#       'outcomes': [{'name': 'FC Pyunik', 'price': 2.9},
#        {'name': 'FC Struga', 'price': 2.2},
#        {'name': 'Draw', 'price': 3.3}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:04Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:04Z',
#       'outcomes': [{'name': 'FC Pyunik', 'price': 3.02},
#        {'name': 'FC Struga', 'price': 2.28},
#        {'name': 'Draw', 'price': 3.34}]}]}]},
#  {'id': '4bac5bdee7b8537d600aec52bd31a507',
#   'sport_key': 'soccer_uefa_europa_conference_league',
#   'sport_title': 'UEFA Europa Conference League',
#   'commence_time': '2024-07-24T17:00:00Z',
#   'home_team': 'FC Dinamo Batumi',
#   'away_team': 'FK Dečić',
#   'bookmakers': [{'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:43Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:43Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.34},
#        {'name': 'FK Dečić', 'price': 9.17},
#        {'name': 'Draw', 'price': 4.58}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:03:04Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:04Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.36},
#        {'name': 'FK Dečić', 'price': 8.0},
#        {'name': 'Draw', 'price': 4.75}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:01:51Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:01:51Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.36},
#        {'name': 'FK Dečić', 'price': 8.0},
#        {'name': 'Draw', 'price': 4.75}]}]},
#    {'key': 'williamhill',
#     'title': 'William Hill',
#     'last_update': '2024-07-24T14:03:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:44Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.3},
#        {'name': 'FK Dečić', 'price': 9.0},
#        {'name': 'Draw', 'price': 4.5}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:04Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:04Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.33},
#        {'name': 'FK Dečić', 'price': 9.2},
#        {'name': 'Draw', 'price': 4.8}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:04Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:04Z',
#       'outcomes': [{'name': 'FC Dinamo Batumi', 'price': 1.35},
#        {'name': 'FK Dečić', 'price': 8.7},
#        {'name': 'Draw', 'price': 4.9}]}]}]},
#  {'id': '179ff7d692c27ebe4f41023a5114bca3',
#   'sport_key': 'soccer_uefa_champs_league_qualification',
#   'sport_title': 'UEFA Champions League Qualification',
#   'commence_time': '2024-07-24T17:30:00Z',
#   'home_team': 'PAOK',
#   'away_team': 'FK Borac Banja Luka',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.25},
#        {'name': 'PAOK', 'price': 1.18},
#        {'name': 'Draw', 'price': 6.8}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#        {'name': 'PAOK', 'price': 1.13},
#        {'name': 'Draw', 'price': 6.5}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:03:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:44Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#        {'name': 'PAOK', 'price': 1.17},
#        {'name': 'Draw', 'price': 6.5}]}]},
#    {'key': 'betclic',
#     'title': 'Betclic',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#        {'name': 'PAOK', 'price': 1.19},
#        {'name': 'Draw', 'price': 6.85}]}]},
#    {'key': 'unibet_eu',
#     'title': 'Unibet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 13.0},
#        {'name': 'PAOK', 'price': 1.18},
#        {'name': 'Draw', 'price': 8.0}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#        {'name': 'PAOK', 'price': 1.17},
#        {'name': 'Draw', 'price': 6.5}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.81},
#        {'name': 'PAOK', 'price': 1.15},
#        {'name': 'Draw', 'price': 8.12}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 11.5},
#        {'name': 'PAOK', 'price': 1.16},
#        {'name': 'Draw', 'price': 7.5}]}]},
#    {'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 18.0},
#        {'name': 'PAOK', 'price': 1.16},
#        {'name': 'Draw', 'price': 7.0}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 12.25},
#        {'name': 'PAOK', 'price': 1.22},
#        {'name': 'Draw', 'price': 6.55}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 23.0},
#        {'name': 'PAOK', 'price': 1.18},
#        {'name': 'Draw', 'price': 8.4}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 29.0},
#        {'name': 'PAOK', 'price': 1.19},
#        {'name': 'Draw', 'price': 9.2}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 17.0},
#        {'name': 'PAOK', 'price': 1.08},
#        {'name': 'Draw', 'price': 9.0}]}]}]},
#  {'id': '72c49c373f786b9db30dab67478a6d31',
#   'sport_key': 'soccer_uefa_champs_league_qualification',
#   'sport_title': 'UEFA Champions League Qualification',
#   'commence_time': '2024-07-24T18:00:00Z',
#   'home_team': 'PFC Ludogorets Razgrad',
#   'away_team': 'FC Dinamo Minsk',
#   'bookmakers': [{'key': 'onexbet',
#     'title': '1xBet',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 10.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.31},
#        {'name': 'Draw', 'price': 5.7}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 8.9},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.32},
#        {'name': 'Draw', 'price': 5.3}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 9.0},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.25},
#        {'name': 'Draw', 'price': 5.0}]}]},
#    {'key': 'betclic',
#     'title': 'Betclic',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 8.95},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.33},
#        {'name': 'Draw', 'price': 5.35}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 10.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.31},
#        {'name': 'Draw', 'price': 5.03}]}]},
#    {'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 9.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.3},
#        {'name': 'Draw', 'price': 5.5}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 10.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.28},
#        {'name': 'Draw', 'price': 5.55}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 9.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.28},
#        {'name': 'Draw', 'price': 5.5}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:03:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:44Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 9.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.28},
#        {'name': 'Draw', 'price': 5.5}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 11.0},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.34},
#        {'name': 'Draw', 'price': 5.9}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 11.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.36},
#        {'name': 'Draw', 'price': 6.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 7.8},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.27},
#        {'name': 'Draw', 'price': 4.95}]}]},
#    {'key': 'unibet_eu',
#     'title': 'Unibet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 10.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.28},
#        {'name': 'Draw', 'price': 5.15}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'FC Dinamo Minsk', 'price': 9.5},
#        {'name': 'PFC Ludogorets Razgrad', 'price': 1.28},
#        {'name': 'Draw', 'price': 4.9}]}]}]},
#  {'id': '6afa39b88aeff4ba7f7651242c9785a2',
#   'sport_key': 'soccer_uefa_champs_league_qualification',
#   'sport_title': 'UEFA Champions League Qualification',
#   'commence_time': '2024-07-24T18:15:00Z',
#   'home_team': 'NK Celje',
#   'away_team': 'ŠK Slovan Bratislava',
#   'bookmakers': [{'key': 'onexbet',
#     'title': '1xBet',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.45},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.86},
#        {'name': 'Draw', 'price': 3.62}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.38},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.83},
#        {'name': 'Draw', 'price': 3.48}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.38},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.75},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'betclic',
#     'title': 'Betclic',
#     'last_update': '2024-07-24T14:03:45Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:45Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.4},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.86},
#        {'name': 'Draw', 'price': 3.52}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.44},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.84},
#        {'name': 'Draw', 'price': 3.47}]}]},
#    {'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.45},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.8},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.39},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.81},
#        {'name': 'Draw', 'price': 3.56}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.4},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.8},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:03:44Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:44Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.4},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.8},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.35},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.85},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'unibet_eu',
#     'title': 'Unibet',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.4},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.9},
#        {'name': 'Draw', 'price': 3.35}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:03:08Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.52},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.94},
#        {'name': 'Draw', 'price': 3.65}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:03:08Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.58},
#        {'name': 'ŠK Slovan Bratislava', 'price': 3.05},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:07Z',
#       'outcomes': [{'name': 'NK Celje', 'price': 2.31},
#        {'name': 'ŠK Slovan Bratislava', 'price': 2.59},
#        {'name': 'Draw', 'price': 3.3}]}]}]},
#  {'id': 'd5f1b884f358d7149277f5e4f0cbb43a',
#   'sport_key': 'soccer_switzerland_superleague',
#   'sport_title': 'Swiss Superleague',
#   'commence_time': '2024-07-24T18:30:00Z',
#   'home_team': 'Servette',
#   'away_team': 'BSC Young Boys',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-07-24T14:03:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:49Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.15},
#        {'name': 'Servette', 'price': 2.15},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.1},
#        {'name': 'Servette', 'price': 2.12},
#        {'name': 'Draw', 'price': 3.84}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.19},
#        {'name': 'Servette', 'price': 2.16},
#        {'name': 'Draw', 'price': 3.79}]}]},
#    {'key': 'betclic',
#     'title': 'Betclic',
#     'last_update': '2024-07-24T14:03:14Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:14Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.15},
#        {'name': 'Servette', 'price': 2.09},
#        {'name': 'Draw', 'price': 3.78}]}]},
#    {'key': 'gtbets',
#     'title': 'GTbets',
#     'last_update': '2024-07-24T14:03:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:49Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.08},
#        {'name': 'Servette', 'price': 2.11},
#        {'name': 'Draw', 'price': 3.82}]}]},
#    {'key': 'suprabets',
#     'title': 'Suprabets',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.32},
#        {'name': 'Servette', 'price': 2.14},
#        {'name': 'Draw', 'price': 3.84}]}]},
#    {'key': 'onexbet',
#     'title': '1xBet',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.08},
#        {'name': 'Servette', 'price': 2.14},
#        {'name': 'Draw', 'price': 3.84}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:02:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:31Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.14},
#        {'name': 'Servette', 'price': 2.09},
#        {'name': 'Draw', 'price': 3.8}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:03:14Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:14Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.35},
#        {'name': 'Servette', 'price': 2.22},
#        {'name': 'Draw', 'price': 3.9}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:03:14Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.4},
#        {'name': 'Servette', 'price': 2.24},
#        {'name': 'Draw', 'price': 3.95}]}]},
#    {'key': 'williamhill',
#     'title': 'William Hill',
#     'last_update': '2024-07-24T14:03:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:49Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.0},
#        {'name': 'Servette', 'price': 2.0},
#        {'name': 'Draw', 'price': 3.7}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 2.89},
#        {'name': 'Servette', 'price': 2.17},
#        {'name': 'Draw', 'price': 3.65}]}]},
#    {'key': 'everygame',
#     'title': 'Everygame',
#     'last_update': '2024-07-24T14:03:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:49Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.05},
#        {'name': 'Servette', 'price': 2.05},
#        {'name': 'Draw', 'price': 3.6}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:03:14Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:14Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 2.95},
#        {'name': 'Servette', 'price': 2.04},
#        {'name': 'Draw', 'price': 3.5}]}]},
#    {'key': 'unibet_eu',
#     'title': 'Unibet',
#     'last_update': '2024-07-24T14:03:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:48Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.1},
#        {'name': 'Servette', 'price': 2.1},
#        {'name': 'Draw', 'price': 3.7}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:03:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:48Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.0},
#        {'name': 'Servette', 'price': 2.15},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:14Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:14Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.0},
#        {'name': 'Servette', 'price': 2.15},
#        {'name': 'Draw', 'price': 3.75}]}]},
#    {'key': 'matchbook',
#     'title': 'Matchbook',
#     'last_update': '2024-07-24T14:03:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.25},
#        {'name': 'Servette', 'price': 2.2},
#        {'name': 'Draw', 'price': 3.9}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:03:13Z',
#       'outcomes': [{'name': 'BSC Young Boys', 'price': 3.4},
#        {'name': 'Servette', 'price': 2.26},
#        {'name': 'Draw', 'price': 4.1}]}]}]},
#  {'id': 'e9fff60b7c68408a5b69ae07503bdef1',
#   'sport_key': 'soccer_argentina_primera_division',
#   'sport_title': 'Primera División - Argentina',
#   'commence_time': '2024-07-24T20:00:00Z',
#   'home_team': 'Talleres',
#   'away_team': 'Defensa y Justicia',
#   'bookmakers': [{'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.5},
#        {'name': 'Talleres', 'price': 1.5},
#        {'name': 'Draw', 'price': 4.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:31Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.5},
#        {'name': 'Talleres', 'price': 1.52},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'onexbet',
#     'title': '1xBet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.4},
#        {'name': 'Talleres', 'price': 1.53},
#        {'name': 'Draw', 'price': 4.15}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.6},
#        {'name': 'Talleres', 'price': 1.51},
#        {'name': 'Draw', 'price': 4.15}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 7.8},
#        {'name': 'Talleres', 'price': 1.57},
#        {'name': 'Draw', 'price': 4.2}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 8.0},
#        {'name': 'Talleres', 'price': 1.58},
#        {'name': 'Draw', 'price': 4.3}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.7},
#        {'name': 'Talleres', 'price': 1.5},
#        {'name': 'Draw', 'price': 4.05}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:32Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:32Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.7},
#        {'name': 'Talleres', 'price': 1.5},
#        {'name': 'Draw', 'price': 4.05}]}]},
#    {'key': 'matchbook',
#     'title': 'Matchbook',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 7.8},
#        {'name': 'Talleres', 'price': 1.57},
#        {'name': 'Draw', 'price': 4.2}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 8.0},
#        {'name': 'Talleres', 'price': 1.58},
#        {'name': 'Draw', 'price': 4.4}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.83},
#        {'name': 'Talleres', 'price': 1.53},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:31Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.8},
#        {'name': 'Talleres', 'price': 1.52},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'everygame',
#     'title': 'Everygame',
#     'last_update': '2024-07-24T14:02:15Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:15Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.5},
#        {'name': 'Talleres', 'price': 1.5},
#        {'name': 'Draw', 'price': 4.0}]}]},
#    {'key': 'betanysports',
#     'title': 'BetAnySports',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.8},
#        {'name': 'Talleres', 'price': 1.51},
#        {'name': 'Draw', 'price': 4.1}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:02:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:49Z',
#       'outcomes': [{'name': 'Defensa y Justicia', 'price': 6.4},
#        {'name': 'Talleres', 'price': 1.47},
#        {'name': 'Draw', 'price': 3.95}]}]}]},
#  {'id': 'd911e455e3847e9798a6ef1c020c02c2',
#   'sport_key': 'soccer_argentina_primera_division',
#   'sport_title': 'Primera División - Argentina',
#   'commence_time': '2024-07-24T20:15:00Z',
#   'home_team': 'Sarmiento de Junin',
#   'away_team': 'Racing Club',
#   'bookmakers': [{'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.91},
#        {'name': 'Sarmiento de Junin', 'price': 4.5},
#        {'name': 'Draw', 'price': 3.2}]}]},
#    {'key': 'betclic',
#     'title': 'Betclic',
#     'last_update': '2024-07-24T13:59:46Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T13:59:46Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.89},
#        {'name': 'Sarmiento de Junin', 'price': 4.3},
#        {'name': 'Draw', 'price': 2.96}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-07-24T14:03:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:31Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.91},
#        {'name': 'Sarmiento de Junin', 'price': 4.6},
#        {'name': 'Draw', 'price': 3.12}]}]},
#    {'key': 'onexbet',
#     'title': '1xBet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.92},
#        {'name': 'Sarmiento de Junin', 'price': 4.52},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'betfair_ex_eu',
#     'title': 'Betfair',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.95},
#        {'name': 'Sarmiento de Junin', 'price': 5.1},
#        {'name': 'Draw', 'price': 3.35}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.96},
#        {'name': 'Sarmiento de Junin', 'price': 5.3},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'marathonbet',
#     'title': 'Marathon Bet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.9},
#        {'name': 'Sarmiento de Junin', 'price': 4.5},
#        {'name': 'Draw', 'price': 3.26}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.91},
#        {'name': 'Sarmiento de Junin', 'price': 4.76},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'nordicbet',
#     'title': 'Nordic Bet',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.9},
#        {'name': 'Sarmiento de Junin', 'price': 4.35},
#        {'name': 'Draw', 'price': 3.2}]}]},
#    {'key': 'betsson',
#     'title': 'Betsson',
#     'last_update': '2024-07-24T14:03:32Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:32Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.9},
#        {'name': 'Sarmiento de Junin', 'price': 4.35},
#        {'name': 'Draw', 'price': 3.2}]}]},
#    {'key': 'matchbook',
#     'title': 'Matchbook',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.95},
#        {'name': 'Sarmiento de Junin', 'price': 5.1},
#        {'name': 'Draw', 'price': 3.35}]},
#      {'key': 'h2h_lay',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.96},
#        {'name': 'Sarmiento de Junin', 'price': 5.3},
#        {'name': 'Draw', 'price': 3.4}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-07-24T14:03:31Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:03:31Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.86},
#        {'name': 'Sarmiento de Junin', 'price': 4.88},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'everygame',
#     'title': 'Everygame',
#     'last_update': '2024-07-24T14:02:15Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:15Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.85},
#        {'name': 'Sarmiento de Junin', 'price': 4.6},
#        {'name': 'Draw', 'price': 3.15}]}]},
#    {'key': 'betanysports',
#     'title': 'BetAnySports',
#     'last_update': '2024-07-24T14:02:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:48Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.87},
#        {'name': 'Sarmiento de Junin', 'price': 4.9},
#        {'name': 'Draw', 'price': 3.25}]}]},
#    {'key': 'livescorebet_eu',
#     'title': 'LiveScore Bet (EU)',
#     'last_update': '2024-07-24T14:02:49Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-07-24T14:02:49Z',
#       'outcomes': [{'name': 'Racing Club', 'price': 1.81},
#        {'name': 'Sarmiento de Junin', 'price': 4.6},
#        {'name': 'Draw', 'price': 3.2}]}]}]}]

# %%
import pandas as pd
def transform_data_to_df(data):
    flattened_data = []

    for match in data:
        for bookmaker in match['bookmakers']:
            for market in bookmaker['markets']:
                for outcome in market['outcomes']:
                    flattened_data.append({
                        'match_id': match['id'],
                        'sport_key': match['sport_key'],
                        'sport_title': match['sport_title'],
                        'commence_time': match['commence_time'],
                        'home_team': match['home_team'],
                        'away_team': match['away_team'],
                        'bookmaker_key': bookmaker['key'],
                        'bookmaker_title': bookmaker['title'],
                        'bookmaker_last_update': bookmaker['last_update'],
                        'market_key': market['key'],
                        'market_last_update': market['last_update'],
                        'outcome_name': outcome['name'],
                        'outcome_price': outcome['price']
                    })

    df = pd.DataFrame(flattened_data)
    return df

# %%
transform_data_to_df(response.json())
# Out:
#                              match_id                             sport_key  \
# 0    51906a682c32df1067d2b7daaf5a35a5  soccer_uefa_europa_conference_league
# 1    51906a682c32df1067d2b7daaf5a35a5  soccer_uefa_europa_conference_league
# 2    51906a682c32df1067d2b7daaf5a35a5  soccer_uefa_europa_conference_league
# 3    51906a682c32df1067d2b7daaf5a35a5  soccer_uefa_europa_conference_league
# 4    51906a682c32df1067d2b7daaf5a35a5  soccer_uefa_europa_conference_league
# ..                                ...                                   ...
# 295  d911e455e3847e9798a6ef1c020c02c2     soccer_argentina_primera_division
# 296  d911e455e3847e9798a6ef1c020c02c2     soccer_argentina_primera_division
# 297  d911e455e3847e9798a6ef1c020c02c2     soccer_argentina_primera_division
# 298  d911e455e3847e9798a6ef1c020c02c2     soccer_argentina_primera_division
# 299  d911e455e3847e9798a6ef1c020c02c2     soccer_argentina_primera_division
#
#                        sport_title         commence_time           home_team  \
# 0    UEFA Europa Conference League  2024-07-24T15:00:00Z           FC Struga
# 1    UEFA Europa Conference League  2024-07-24T15:00:00Z           FC Struga
# 2    UEFA Europa Conference League  2024-07-24T15:00:00Z           FC Struga
# 3    UEFA Europa Conference League  2024-07-24T15:00:00Z           FC Struga
# 4    UEFA Europa Conference League  2024-07-24T15:00:00Z           FC Struga
# ..                             ...                   ...                 ...
# 295   Primera División - Argentina  2024-07-24T20:15:00Z  Sarmiento de Junin
# 296   Primera División - Argentina  2024-07-24T20:15:00Z  Sarmiento de Junin
# 297   Primera División - Argentina  2024-07-24T20:15:00Z  Sarmiento de Junin
# 298   Primera División - Argentina  2024-07-24T20:15:00Z  Sarmiento de Junin
# 299   Primera División - Argentina  2024-07-24T20:15:00Z  Sarmiento de Junin
#
#        away_team    bookmaker_key     bookmaker_title bookmaker_last_update  \
# 0      FC Pyunik         pinnacle            Pinnacle  2024-07-24T14:03:43Z
# 1      FC Pyunik         pinnacle            Pinnacle  2024-07-24T14:03:43Z
# 2      FC Pyunik         pinnacle            Pinnacle  2024-07-24T14:03:43Z
# 3      FC Pyunik      williamhill        William Hill  2024-07-24T14:03:44Z
# 4      FC Pyunik      williamhill        William Hill  2024-07-24T14:03:44Z
# ..           ...              ...                 ...                   ...
# 295  Racing Club     betanysports        BetAnySports  2024-07-24T14:02:48Z
# 296  Racing Club     betanysports        BetAnySports  2024-07-24T14:02:48Z
# 297  Racing Club  livescorebet_eu  LiveScore Bet (EU)  2024-07-24T14:02:49Z
# 298  Racing Club  livescorebet_eu  LiveScore Bet (EU)  2024-07-24T14:02:49Z
# 299  Racing Club  livescorebet_eu  LiveScore Bet (EU)  2024-07-24T14:02:49Z
#
#     market_key    market_last_update        outcome_name  outcome_price
# 0          h2h  2024-07-24T14:03:43Z           FC Pyunik           3.12
# 1          h2h  2024-07-24T14:03:43Z           FC Struga           2.37
# 2          h2h  2024-07-24T14:03:43Z                Draw           3.10
# 3          h2h  2024-07-24T14:03:44Z           FC Pyunik           2.90
# 4          h2h  2024-07-24T14:03:44Z           FC Struga           2.20
# ..         ...                   ...                 ...            ...
# 295        h2h  2024-07-24T14:02:48Z  Sarmiento de Junin           4.90
# 296        h2h  2024-07-24T14:02:48Z                Draw           3.25
# 297        h2h  2024-07-24T14:02:49Z         Racing Club           1.81
# 298        h2h  2024-07-24T14:02:49Z  Sarmiento de Junin           4.60
# 299        h2h  2024-07-24T14:02:49Z                Draw           3.20
#
# [300 rows x 13 columns]

# %%
[sport['sport_key'] for sport in response.json()]
# Out:
# ['soccer_uefa_europa_conference_league',
#  'soccer_uefa_europa_conference_league',
#  'soccer_uefa_champs_league_qualification',
#  'soccer_uefa_champs_league_qualification',
#  'soccer_uefa_champs_league_qualification',
#  'soccer_switzerland_superleague',
#  'soccer_argentina_primera_division',
#  'soccer_argentina_primera_division']

# %%
response.json()[2]
# Out:
# {'id': '179ff7d692c27ebe4f41023a5114bca3',
#  'sport_key': 'soccer_uefa_champs_league_qualification',
#  'sport_title': 'UEFA Champions League Qualification',
#  'commence_time': '2024-07-24T17:30:00Z',
#  'home_team': 'PAOK',
#  'away_team': 'FK Borac Banja Luka',
#  'bookmakers': [{'key': 'mybookieag',
#    'title': 'MyBookie.ag',
#    'last_update': '2024-07-24T14:03:45Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:45Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.25},
#       {'name': 'PAOK', 'price': 1.18},
#       {'name': 'Draw', 'price': 6.8}]}]},
#   {'key': 'sport888',
#    'title': '888sport',
#    'last_update': '2024-07-24T14:03:07Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:07Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#       {'name': 'PAOK', 'price': 1.13},
#       {'name': 'Draw', 'price': 6.5}]}]},
#   {'key': 'nordicbet',
#    'title': 'Nordic Bet',
#    'last_update': '2024-07-24T14:03:44Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:44Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#       {'name': 'PAOK', 'price': 1.17},
#       {'name': 'Draw', 'price': 6.5}]}]},
#   {'key': 'betclic',
#    'title': 'Betclic',
#    'last_update': '2024-07-24T14:03:45Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:45Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#       {'name': 'PAOK', 'price': 1.19},
#       {'name': 'Draw', 'price': 6.85}]}]},
#   {'key': 'unibet_eu',
#    'title': 'Unibet',
#    'last_update': '2024-07-24T14:03:08Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:08Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 13.0},
#       {'name': 'PAOK', 'price': 1.18},
#       {'name': 'Draw', 'price': 8.0}]}]},
#   {'key': 'betsson',
#    'title': 'Betsson',
#    'last_update': '2024-07-24T14:03:07Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:07Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.0},
#       {'name': 'PAOK', 'price': 1.17},
#       {'name': 'Draw', 'price': 6.5}]}]},
#   {'key': 'pinnacle',
#    'title': 'Pinnacle',
#    'last_update': '2024-07-24T14:03:07Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:07Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 15.81},
#       {'name': 'PAOK', 'price': 1.15},
#       {'name': 'Draw', 'price': 8.12}]}]},
#   {'key': 'livescorebet_eu',
#    'title': 'LiveScore Bet (EU)',
#    'last_update': '2024-07-24T14:03:08Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:08Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 11.5},
#       {'name': 'PAOK', 'price': 1.16},
#       {'name': 'Draw', 'price': 7.5}]}]},
#   {'key': 'coolbet',
#    'title': 'Coolbet',
#    'last_update': '2024-07-24T14:03:08Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:08Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 18.0},
#       {'name': 'PAOK', 'price': 1.16},
#       {'name': 'Draw', 'price': 7.0}]}]},
#   {'key': 'marathonbet',
#    'title': 'Marathon Bet',
#    'last_update': '2024-07-24T14:03:07Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:07Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 12.25},
#       {'name': 'PAOK', 'price': 1.22},
#       {'name': 'Draw', 'price': 6.55}]}]},
#   {'key': 'betfair_ex_eu',
#    'title': 'Betfair',
#    'last_update': '2024-07-24T14:03:08Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:08Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 23.0},
#       {'name': 'PAOK', 'price': 1.18},
#       {'name': 'Draw', 'price': 8.4}]},
#     {'key': 'h2h_lay',
#      'last_update': '2024-07-24T14:03:08Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 29.0},
#       {'name': 'PAOK', 'price': 1.19},
#       {'name': 'Draw', 'price': 9.2}]}]},
#   {'key': 'betonlineag',
#    'title': 'BetOnline.ag',
#    'last_update': '2024-07-24T14:03:07Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2024-07-24T14:03:07Z',
#      'outcomes': [{'name': 'FK Borac Banja Luka', 'price': 17.0},
#       {'name': 'PAOK', 'price': 1.08},
#       {'name': 'Draw', 'price': 9.0}]}]}]}

# %%
[bookie['bookmakers'] for bookie in response.json()[0]['bookmakers']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 [bookie['bookmakers'] for bookie in response.json()[0]['bookmakers']]
#
# Cell In[34], line 1, in <listcomp>(.0)
# ----> 1 [bookie['bookmakers'] for bookie in response.json()[0]['bookmakers']]
#
# KeyError: 'bookmakers'

# %%
url = f'https://api.the-odds-api.com/v4/sports/?apiKey={apiKey}'
response_sports = requests.get(url)
response_sports.json()
# Out:
# [{'key': 'americanfootball_cfl',
#   'group': 'American Football',
#   'title': 'CFL',
#   'description': 'Canadian Football League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'americanfootball_ncaaf',
#   'group': 'American Football',
#   'title': 'NCAAF',
#   'description': 'US College Football',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'americanfootball_ncaaf_championship_winner',
#   'group': 'American Football',
#   'title': 'NCAAF Championship Winner',
#   'description': 'US College Football Championship Winner',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'americanfootball_nfl',
#   'group': 'American Football',
#   'title': 'NFL',
#   'description': 'US Football',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'americanfootball_nfl_preseason',
#   'group': 'American Football',
#   'title': 'NFL Preseason',
#   'description': 'US Football',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'americanfootball_nfl_super_bowl_winner',
#   'group': 'American Football',
#   'title': 'NFL Super Bowl Winner',
#   'description': 'Super Bowl Winner 2024/2025',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'aussierules_afl',
#   'group': 'Aussie Rules',
#   'title': 'AFL',
#   'description': 'Aussie Football',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'baseball_kbo',
#   'group': 'Baseball',
#   'title': 'KBO',
#   'description': 'KBO League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'baseball_milb',
#   'group': 'Baseball',
#   'title': 'MiLB',
#   'description': 'Minor League Baseball',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'baseball_mlb',
#   'group': 'Baseball',
#   'title': 'MLB',
#   'description': 'Major League Baseball',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'baseball_mlb_world_series_winner',
#   'group': 'Baseball',
#   'title': 'MLB World Series Winner',
#   'description': 'World Series Winner 2024',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'basketball_nba_championship_winner',
#   'group': 'Basketball',
#   'title': 'NBA Championship Winner',
#   'description': 'Championship Winner 2024/2025',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'basketball_ncaab_championship_winner',
#   'group': 'Basketball',
#   'title': 'NCAAB Championship Winner',
#   'description': 'US College Basketball Championship Winner',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'boxing_boxing',
#   'group': 'Boxing',
#   'title': 'Boxing',
#   'description': 'Boxing Bouts',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'cricket_odi',
#   'group': 'Cricket',
#   'title': 'One Day Internationals',
#   'description': 'One Day Internationals',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'cricket_t20_blast',
#   'group': 'Cricket',
#   'title': 'T20 Blast',
#   'description': 'T20 Blast',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'cricket_test_match',
#   'group': 'Cricket',
#   'title': 'Test Matches',
#   'description': 'International Test Matches',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'cricket_the_hundred',
#   'group': 'Cricket',
#   'title': 'The Hundred',
#   'description': 'The Hundred',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'golf_masters_tournament_winner',
#   'group': 'Golf',
#   'title': 'Masters Tournament Winner',
#   'description': '2025 Winner',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'golf_pga_championship_winner',
#   'group': 'Golf',
#   'title': 'PGA Championship Winner',
#   'description': '2025 Winner',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'icehockey_nhl',
#   'group': 'Ice Hockey',
#   'title': 'NHL',
#   'description': 'US Ice Hockey',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'icehockey_nhl_championship_winner',
#   'group': 'Ice Hockey',
#   'title': 'NHL Championship Winner',
#   'description': 'Stanley Cup Winner 2024/2025',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'icehockey_sweden_hockey_league',
#   'group': 'Ice Hockey',
#   'title': 'SHL',
#   'description': 'Swedish Hockey League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'lacrosse_pll',
#   'group': 'Lacrosse',
#   'title': 'PLL',
#   'description': 'Premier Lacrosse League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'mma_mixed_martial_arts',
#   'group': 'Mixed Martial Arts',
#   'title': 'MMA',
#   'description': 'Mixed Martial Arts',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'politics_us_presidential_election_winner',
#   'group': 'Politics',
#   'title': 'US Presidential Elections Winner',
#   'description': '2024 US Presidential Election Winner',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'rugbyleague_nrl',
#   'group': 'Rugby League',
#   'title': 'NRL',
#   'description': 'Aussie Rugby League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_argentina_primera_division',
#   'group': 'Soccer',
#   'title': 'Primera División - Argentina',
#   'description': 'Argentine Primera División',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_austria_bundesliga',
#   'group': 'Soccer',
#   'title': 'Austrian Football Bundesliga',
#   'description': 'Austrian Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_belgium_first_div',
#   'group': 'Soccer',
#   'title': 'Belgium First Div',
#   'description': 'Belgian First Division A',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_brazil_campeonato',
#   'group': 'Soccer',
#   'title': 'Brazil Série A',
#   'description': 'Brasileirão Série A',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_brazil_serie_b',
#   'group': 'Soccer',
#   'title': 'Brazil Série B',
#   'description': 'Campeonato Brasileiro Série B',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_chile_campeonato',
#   'group': 'Soccer',
#   'title': 'Primera División - Chile',
#   'description': 'Campeonato Chileno',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_china_superleague',
#   'group': 'Soccer',
#   'title': 'Super League - China',
#   'description': 'Chinese Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_conmebol_copa_libertadores',
#   'group': 'Soccer',
#   'title': 'Copa Libertadores',
#   'description': 'CONMEBOL Copa Libertadores',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_denmark_superliga',
#   'group': 'Soccer',
#   'title': 'Denmark Superliga',
#   'description': 'Danish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_efl_champ',
#   'group': 'Soccer',
#   'title': 'Championship',
#   'description': 'EFL Championship',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_england_efl_cup',
#   'group': 'Soccer',
#   'title': 'EFL Cup',
#   'description': 'League Cup',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_england_league1',
#   'group': 'Soccer',
#   'title': 'League 1',
#   'description': 'EFL League 1',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_england_league2',
#   'group': 'Soccer',
#   'title': 'League 2',
#   'description': 'EFL League 2 ',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_epl',
#   'group': 'Soccer',
#   'title': 'EPL',
#   'description': 'English Premier League',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_fifa_world_cup_winner',
#   'group': 'Soccer',
#   'title': 'FIFA World Cup Winner',
#   'description': 'FIFA World Cup Winner 2026',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'soccer_finland_veikkausliiga',
#   'group': 'Soccer',
#   'title': 'Veikkausliiga - Finland',
#   'description': 'Finnish  Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_france_ligue_one',
#   'group': 'Soccer',
#   'title': 'Ligue 1 - France',
#   'description': 'French Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_france_ligue_two',
#   'group': 'Soccer',
#   'title': 'Ligue 2 - France',
#   'description': 'French Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_germany_bundesliga',
#   'group': 'Soccer',
#   'title': 'Bundesliga - Germany',
#   'description': 'German Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_germany_bundesliga2',
#   'group': 'Soccer',
#   'title': 'Bundesliga 2 - Germany',
#   'description': 'German Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_germany_liga3',
#   'group': 'Soccer',
#   'title': '3. Liga - Germany',
#   'description': 'German Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_greece_super_league',
#   'group': 'Soccer',
#   'title': 'Super League - Greece',
#   'description': 'Greek Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_italy_serie_a',
#   'group': 'Soccer',
#   'title': 'Serie A - Italy',
#   'description': 'Italian Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_italy_serie_b',
#   'group': 'Soccer',
#   'title': 'Serie B - Italy',
#   'description': 'Italian Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_korea_kleague1',
#   'group': 'Soccer',
#   'title': 'K League 1',
#   'description': 'Korean Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_league_of_ireland',
#   'group': 'Soccer',
#   'title': 'League of Ireland',
#   'description': 'Airtricity League Premier Division',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_netherlands_eredivisie',
#   'group': 'Soccer',
#   'title': 'Dutch Eredivisie',
#   'description': 'Dutch Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_norway_eliteserien',
#   'group': 'Soccer',
#   'title': 'Eliteserien - Norway',
#   'description': 'Norwegian Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_poland_ekstraklasa',
#   'group': 'Soccer',
#   'title': 'Ekstraklasa - Poland',
#   'description': 'Polish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_portugal_primeira_liga',
#   'group': 'Soccer',
#   'title': 'Primeira Liga - Portugal',
#   'description': 'Portugese Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_spain_la_liga',
#   'group': 'Soccer',
#   'title': 'La Liga - Spain',
#   'description': 'Spanish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_spain_segunda_division',
#   'group': 'Soccer',
#   'title': 'La Liga 2 - Spain',
#   'description': 'Spanish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_spl',
#   'group': 'Soccer',
#   'title': 'Premiership - Scotland',
#   'description': 'Scottish Premiership',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_sweden_allsvenskan',
#   'group': 'Soccer',
#   'title': 'Allsvenskan - Sweden',
#   'description': 'Swedish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_sweden_superettan',
#   'group': 'Soccer',
#   'title': 'Superettan - Sweden',
#   'description': 'Swedish Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_switzerland_superleague',
#   'group': 'Soccer',
#   'title': 'Swiss Superleague',
#   'description': 'Swiss Soccer',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_uefa_champs_league_qualification',
#   'group': 'Soccer',
#   'title': 'UEFA Champions League Qualification',
#   'description': 'European Champions League Qualification',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'soccer_uefa_europa_conference_league',
#   'group': 'Soccer',
#   'title': 'UEFA Europa Conference League',
#   'description': 'UEFA Europa Conference League',
#   'active': True,
#   'has_outrights': False}]

# %%
sports = [{'key': 'americanfootball_cfl',
  'group': 'American Football',
  'title': 'CFL',
  'description': 'Canadian Football League',
  'active': True,
  'has_outrights': False},
 {'key': 'americanfootball_ncaaf',
  'group': 'American Football',
  'title': 'NCAAF',
  'description': 'US College Football',
  'active': True,
  'has_outrights': False},
 {'key': 'americanfootball_ncaaf_championship_winner',
  'group': 'American Football',
  'title': 'NCAAF Championship Winner',
  'description': 'US College Football Championship Winner',
  'active': True,
  'has_outrights': True},
 {'key': 'americanfootball_nfl',
  'group': 'American Football',
  'title': 'NFL',
  'description': 'US Football',
  'active': True,
  'has_outrights': False},
 {'key': 'americanfootball_nfl_preseason',
  'group': 'American Football',
  'title': 'NFL Preseason',
  'description': 'US Football',
  'active': True,
  'has_outrights': False},
 {'key': 'americanfootball_nfl_super_bowl_winner',
  'group': 'American Football',
  'title': 'NFL Super Bowl Winner',
  'description': 'Super Bowl Winner 2024/2025',
  'active': True,
  'has_outrights': True},
 {'key': 'aussierules_afl',
  'group': 'Aussie Rules',
  'title': 'AFL',
  'description': 'Aussie Football',
  'active': True,
  'has_outrights': False},
 {'key': 'baseball_kbo',
  'group': 'Baseball',
  'title': 'KBO',
  'description': 'KBO League',
  'active': True,
  'has_outrights': False},
 {'key': 'baseball_milb',
  'group': 'Baseball',
  'title': 'MiLB',
  'description': 'Minor League Baseball',
  'active': True,
  'has_outrights': False},
 {'key': 'baseball_mlb',
  'group': 'Baseball',
  'title': 'MLB',
  'description': 'Major League Baseball',
  'active': True,
  'has_outrights': False},
 {'key': 'baseball_mlb_world_series_winner',
  'group': 'Baseball',
  'title': 'MLB World Series Winner',
  'description': 'World Series Winner 2024',
  'active': True,
  'has_outrights': True},
 {'key': 'basketball_nba_championship_winner',
  'group': 'Basketball',
  'title': 'NBA Championship Winner',
  'description': 'Championship Winner 2024/2025',
  'active': True,
  'has_outrights': True},
 {'key': 'basketball_ncaab_championship_winner',
  'group': 'Basketball',
  'title': 'NCAAB Championship Winner',
  'description': 'US College Basketball Championship Winner',
  'active': True,
  'has_outrights': True},
 {'key': 'boxing_boxing',
  'group': 'Boxing',
  'title': 'Boxing',
  'description': 'Boxing Bouts',
  'active': True,
  'has_outrights': False},
 {'key': 'cricket_odi',
  'group': 'Cricket',
  'title': 'One Day Internationals',
  'description': 'One Day Internationals',
  'active': True,
  'has_outrights': False},
 {'key': 'cricket_t20_blast',
  'group': 'Cricket',
  'title': 'T20 Blast',
  'description': 'T20 Blast',
  'active': True,
  'has_outrights': False},
 {'key': 'cricket_test_match',
  'group': 'Cricket',
  'title': 'Test Matches',
  'description': 'International Test Matches',
  'active': True,
  'has_outrights': False},
 {'key': 'cricket_the_hundred',
  'group': 'Cricket',
  'title': 'The Hundred',
  'description': 'The Hundred',
  'active': True,
  'has_outrights': False},
 {'key': 'golf_masters_tournament_winner',
  'group': 'Golf',
  'title': 'Masters Tournament Winner',
  'description': '2025 Winner',
  'active': True,
  'has_outrights': True},
 {'key': 'golf_pga_championship_winner',
  'group': 'Golf',
  'title': 'PGA Championship Winner',
  'description': '2025 Winner',
  'active': True,
  'has_outrights': True},
 {'key': 'icehockey_nhl',
  'group': 'Ice Hockey',
  'title': 'NHL',
  'description': 'US Ice Hockey',
  'active': True,
  'has_outrights': False},
 {'key': 'icehockey_nhl_championship_winner',
  'group': 'Ice Hockey',
  'title': 'NHL Championship Winner',
  'description': 'Stanley Cup Winner 2024/2025',
  'active': True,
  'has_outrights': True},
 {'key': 'icehockey_sweden_hockey_league',
  'group': 'Ice Hockey',
  'title': 'SHL',
  'description': 'Swedish Hockey League',
  'active': True,
  'has_outrights': False},
 {'key': 'lacrosse_pll',
  'group': 'Lacrosse',
  'title': 'PLL',
  'description': 'Premier Lacrosse League',
  'active': True,
  'has_outrights': False},
 {'key': 'mma_mixed_martial_arts',
  'group': 'Mixed Martial Arts',
  'title': 'MMA',
  'description': 'Mixed Martial Arts',
  'active': True,
  'has_outrights': False},
 {'key': 'politics_us_presidential_election_winner',
  'group': 'Politics',
  'title': 'US Presidential Elections Winner',
  'description': '2024 US Presidential Election Winner',
  'active': True,
  'has_outrights': True},
 {'key': 'rugbyleague_nrl',
  'group': 'Rugby League',
  'title': 'NRL',
  'description': 'Aussie Rugby League',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_argentina_primera_division',
  'group': 'Soccer',
  'title': 'Primera División - Argentina',
  'description': 'Argentine Primera División',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_austria_bundesliga',
  'group': 'Soccer',
  'title': 'Austrian Football Bundesliga',
  'description': 'Austrian Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_belgium_first_div',
  'group': 'Soccer',
  'title': 'Belgium First Div',
  'description': 'Belgian First Division A',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_brazil_campeonato',
  'group': 'Soccer',
  'title': 'Brazil Série A',
  'description': 'Brasileirão Série A',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_brazil_serie_b',
  'group': 'Soccer',
  'title': 'Brazil Série B',
  'description': 'Campeonato Brasileiro Série B',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_chile_campeonato',
  'group': 'Soccer',
  'title': 'Primera División - Chile',
  'description': 'Campeonato Chileno',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_china_superleague',
  'group': 'Soccer',
  'title': 'Super League - China',
  'description': 'Chinese Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_conmebol_copa_libertadores',
  'group': 'Soccer',
  'title': 'Copa Libertadores',
  'description': 'CONMEBOL Copa Libertadores',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_denmark_superliga',
  'group': 'Soccer',
  'title': 'Denmark Superliga',
  'description': 'Danish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_efl_champ',
  'group': 'Soccer',
  'title': 'Championship',
  'description': 'EFL Championship',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_england_efl_cup',
  'group': 'Soccer',
  'title': 'EFL Cup',
  'description': 'League Cup',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_england_league1',
  'group': 'Soccer',
  'title': 'League 1',
  'description': 'EFL League 1',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_england_league2',
  'group': 'Soccer',
  'title': 'League 2',
  'description': 'EFL League 2 ',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_epl',
  'group': 'Soccer',
  'title': 'EPL',
  'description': 'English Premier League',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_fifa_world_cup_winner',
  'group': 'Soccer',
  'title': 'FIFA World Cup Winner',
  'description': 'FIFA World Cup Winner 2026',
  'active': True,
  'has_outrights': True},
 {'key': 'soccer_finland_veikkausliiga',
  'group': 'Soccer',
  'title': 'Veikkausliiga - Finland',
  'description': 'Finnish  Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_france_ligue_one',
  'group': 'Soccer',
  'title': 'Ligue 1 - France',
  'description': 'French Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_france_ligue_two',
  'group': 'Soccer',
  'title': 'Ligue 2 - France',
  'description': 'French Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_germany_bundesliga',
  'group': 'Soccer',
  'title': 'Bundesliga - Germany',
  'description': 'German Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_germany_bundesliga2',
  'group': 'Soccer',
  'title': 'Bundesliga 2 - Germany',
  'description': 'German Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_germany_liga3',
  'group': 'Soccer',
  'title': '3. Liga - Germany',
  'description': 'German Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_greece_super_league',
  'group': 'Soccer',
  'title': 'Super League - Greece',
  'description': 'Greek Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_italy_serie_a',
  'group': 'Soccer',
  'title': 'Serie A - Italy',
  'description': 'Italian Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_italy_serie_b',
  'group': 'Soccer',
  'title': 'Serie B - Italy',
  'description': 'Italian Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_korea_kleague1',
  'group': 'Soccer',
  'title': 'K League 1',
  'description': 'Korean Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_league_of_ireland',
  'group': 'Soccer',
  'title': 'League of Ireland',
  'description': 'Airtricity League Premier Division',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_netherlands_eredivisie',
  'group': 'Soccer',
  'title': 'Dutch Eredivisie',
  'description': 'Dutch Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_norway_eliteserien',
  'group': 'Soccer',
  'title': 'Eliteserien - Norway',
  'description': 'Norwegian Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_poland_ekstraklasa',
  'group': 'Soccer',
  'title': 'Ekstraklasa - Poland',
  'description': 'Polish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_portugal_primeira_liga',
  'group': 'Soccer',
  'title': 'Primeira Liga - Portugal',
  'description': 'Portugese Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_spain_la_liga',
  'group': 'Soccer',
  'title': 'La Liga - Spain',
  'description': 'Spanish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_spain_segunda_division',
  'group': 'Soccer',
  'title': 'La Liga 2 - Spain',
  'description': 'Spanish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_spl',
  'group': 'Soccer',
  'title': 'Premiership - Scotland',
  'description': 'Scottish Premiership',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_sweden_allsvenskan',
  'group': 'Soccer',
  'title': 'Allsvenskan - Sweden',
  'description': 'Swedish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_sweden_superettan',
  'group': 'Soccer',
  'title': 'Superettan - Sweden',
  'description': 'Swedish Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_switzerland_superleague',
  'group': 'Soccer',
  'title': 'Swiss Superleague',
  'description': 'Swiss Soccer',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_uefa_champs_league_qualification',
  'group': 'Soccer',
  'title': 'UEFA Champions League Qualification',
  'description': 'European Champions League Qualification',
  'active': True,
  'has_outrights': False},
 {'key': 'soccer_uefa_europa_conference_league',
  'group': 'Soccer',
  'title': 'UEFA Europa Conference League',
  'description': 'UEFA Europa Conference League',
  'active': True,
  'has_outrights': False}]
