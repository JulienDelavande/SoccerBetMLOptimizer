# %%
import optibet_lib.soccerdata as sd
# Out:
# [09/17/25 12:29:33] INFO     No custom team name replacements found. You can configure these in       ]8;id=857582;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_config.py\_config.py]8;;\:]8;id=701757;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_config.py#87\87]8;;\
#                              lib/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=552012;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_config.py\_config.py]8;;\:]8;id=1322;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_config.py#182\182]8;;\
#                              lib/soccerdata/config/league_dict.json.

# %%
sofifa_all = sd.SoFIFA(versions="latest", no_cache=True)
teams_name = ["SK Slavia Praha", "FK Bodø/Glimt", "Ajax"]
team_ratings_all = sofifa_all.read_team_ratings_by_name(teams_name)
# Out:
# [09/17/25 12:29:41] INFO     Saving cached data to lib/soccerdata/data/SoFIFA                         ]8;id=326894;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_common.py\_common.py]8;;\:]8;id=969139;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_common.py#92\92]8;;\
# [09/17/25 12:30:07] INFO     Searching for team 'SK Slavia Praha' in version Jul 17, 2025...          ]8;id=931018;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=201972;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/sofifa.py#518\518]8;;\

# %%
team_ratings_all
# Out:
#                 overall attack midfield defence transfer_budget club_worth  \
# team
# SK Slavia Praha      74     73       75      74              €0       €65M
#
#                 build_up_speed build_up_dribbling build_up_passing  \
# team
# SK Slavia Praha           Slow             Little            Short
#
#                 build_up_positioning  ... defence_pressure defence_team_width  \
# team                                  ...
# SK Slavia Praha            Organised  ...             Deep             Narrow
#
#                 defence_defender_line defence_domestic_prestige  \
# team
# SK Slavia Praha                 Cover                        10
#
#                 international_prestige players starting_xi_average_age  \
# team
# SK Slavia Praha                      4      27                   26.64
#
#                 whole_team_average_age fifa_edition        update
# team
# SK Slavia Praha                  23.89        FC 25  Jul 17, 2025
#
# [1 rows x 25 columns]

# %%
sofifa_all = sd.SoFIFA(versions="latest", no_cache=False)
team_ratings_all = sofifa_all.read_team_ratings()
team_ratings_all
# Out:
# [09/17/25 12:27:26] INFO     Saving cached data to lib/soccerdata/data/SoFIFA                         ]8;id=363071;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_common.py\_common.py]8;;\:]8;id=732769;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/_common.py#92\92]8;;\
#                     INFO     [1/5] Retrieving teams for ENG-Premier League in Jul 17, 2025 edition    ]8;id=252417;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=370219;file:///Users/huggingfaceit/code/SoccerBetMLOptimizer/optibet_lib/src/optibet_lib/soccerdata/sofifa.py#346\346]8;;\
# ...
