# %%
import soccerdata as sd
import pandas as pd
import matplotlib.pyplot as plt

# %%
sofifa = sd.SoFIFA(versions="all", no_cache=False)
# Out:
# [06/11/24 10:02:04] INFO     Saving cached data to C:\Users\jdelavande\soccerdata\data\SoFIFA         ]8;id=839677;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=60287;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_common.py#92\92]8;;\

# %%
team_ratings = sofifa.read_team_ratings()
team_ratings
# Out:
# [06/11/24 10:02:06] INFO     [1/3810] Retrieving teams for ENG-Premier League in Aug 30, 2006 edition ]8;id=762751;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\sofifa.py\sofifa.py]8;;\:]8;id=506095;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\sofifa.py#346\346]8;;\
#                     INFO     [2/3810] Retrieving teams for ENG-Premier League in Feb 22, 2007 edition ]8;id=655506;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\sofifa.py\sofifa.py]8;;\:]8;id=780360;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\sofifa.py#346\346]8;;\
# ...

# %%
team_ratings
# Out:
#                                    overall attack midfield defence  \
# league             team
# ENG-Premier League AFC Bournemouth      76     79       75      74
#                    AFC Bournemouth      76     79       75      74
#                    AFC Bournemouth      76     79       75      74
#                    AFC Bournemouth      76     79       75      74
#                    AFC Bournemouth      76     79       75      74
# ...                                    ...    ...      ...     ...
# ITA-Serie A        Venezia              72     73       72      72
#                    Venezia              72     73       72      72
#                    Venezia              72     73       72      72
#                    Venezia              72     73       72      72
#                    Venezia              72     73       72      72
#
#                                    transfer_budget club_worth build_up_speed  \
# league             team
# ...

# %%
team_ratings.reset_index(inplace=True)
team_ratings['update'] = team_ratings['update'].apply(lambda x: pd.to_datetime(x))
team_ratings["overall"] = team_ratings["overall"].astype(int)
team_ratings["attack"] = team_ratings["attack"].astype(int)
team_ratings["midfield"] = team_ratings["midfield"].astype(int)
team_ratings["defence"] = team_ratings["defence"].astype(int)
#team_ratings["transfer_budget"] = team_ratings["transfer_budget"].str.replace("€", "").str.replace("M", "0000").str.replace("K", "000").str.replace(".", "").astype(int)
team_ratings["club_worth"] = team_ratings["club_worth"].str.replace("€", "").str.replace("M", "0000").str.replace("K", "000").str.replace("B", "000000000").str.replace(".", "").astype(float)
team_ratings["defence_domestic_prestige"] = team_ratings["defence_domestic_prestige"].astype(int)
team_ratings["international_prestige"] = team_ratings["international_prestige"].astype(int)
team_ratings["players"] = team_ratings["players"].astype(int)
team_ratings["starting_xi_average_age"] = team_ratings["starting_xi_average_age"].astype(float)
team_ratings["whole_team_average_age"] = team_ratings["whole_team_average_age"].astype(float)
team_ratings.sort_values('update', ascending=False)
# Out:
#                                       overall  attack  midfield  defence  \
# league             team
# ESP-La Liga        Las Palmas              75      75        76       74
#                    Real Madrid             85      87        86       84
# ITA-Serie A        Salernitana             74      72        73       72
#                    Fiorentina              78      78        78       74
# ESP-La Liga        Osasuna                 76      77        76       75
# ...                                       ...     ...       ...      ...
# ITA-Serie A        Genoa                   73      76        74       71
# ESP-La Liga        Valencia                75      74        75       75
# ITA-Serie A        Hellas Verona           73      72        74       72
# ENG-Premier League Manchester United       81      78        78       82
#                    AFC Bournemouth         76      79        75       74
#
# ...

# %%
team_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74484 entries, 0 to 74483
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   league                       74484 non-null  object
#  1   team                         74484 non-null  object
#  2   overall                      74484 non-null  int32
#  3   attack                       74484 non-null  int32
#  4   midfield                     74484 non-null  int32
#  5   defence                      74484 non-null  int32
#  6   transfer_budget              74484 non-null  int32
#  7   club_worth                   74484 non-null  float64
#  8   build_up_speed               74484 non-null  object
#  9   build_up_dribbling           74484 non-null  object
#  10  build_up_passing             74484 non-null  object
#  11  build_up_positioning         74484 non-null  object
#  12  chance_creation_crossing     74484 non-null  object
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(team_ratings[team_ratings["team"] == "Real Madrid"]['update'], team_ratings[team_ratings["team"] == "Real Madrid"]['overall'], label='Overall')
ax.plot(team_ratings[team_ratings["team"] == "Real Madrid"]['update'], team_ratings[team_ratings["team"] == "Real Madrid"]['attack'], label='Attack')
ax.plot(team_ratings[team_ratings["team"] == "Real Madrid"]['update'], team_ratings[team_ratings["team"] == "Real Madrid"]['midfield'], label='Midfield')
ax.plot(team_ratings[team_ratings["team"] == "Real Madrid"]['update'], team_ratings[team_ratings["team"] == "Real Madrid"]['defence'], label='Defence')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(team_ratings[team_ratings["team"] == "Real Madrid"]['update'], team_ratings[team_ratings["team"] == "Real Madrid"]['club_worth'], label='club_worth')
ax.legend()
plt.show()

# %%
team_ratings.plot(x='update', y='overall', kind='line')
# Out:
#            overall attack midfield defence transfer_budget club_worth  \
# update
# 2006-08-30      76     79       75      74              €0    €215.5M
# 2007-02-22      76     79       75      74              €0    €215.5M
# 2007-08-30      76     79       75      74              €0    €215.5M
# 2008-02-22      76     79       75      74              €0    €215.5M
# 2008-08-30      76     79       75      74              €0    €215.5M
# ...            ...    ...      ...     ...             ...        ...
# 2022-07-21      72     73       72      72             €4M       €14M
# 2022-07-26      72     73       72      72             €4M       €14M
# 2022-08-09      72     73       72      72             €4M       €14M
# 2022-08-15      72     73       72      72             €4M       €14M
# 2022-08-18      72     73       72      72             €4M       €14M
#
#            build_up_speed build_up_dribbling build_up_passing  \
# update
# ...

# %%
team_ratings.index.unique()
# Out:
# MultiIndex([('ENG-Premier League',        'AFC Bournemouth'),
#             ('ENG-Premier League',                'Arsenal'),
#             ('ENG-Premier League',            'Aston Villa'),
#             ('ENG-Premier League',        'Birmingham City'),
#             ('ENG-Premier League',       'Blackburn Rovers'),
#             ('ENG-Premier League',              'Blackpool'),
#             ('ENG-Premier League',       'Bolton Wanderers'),
#             ('ENG-Premier League',              'Brentford'),
#             ('ENG-Premier League', 'Brighton & Hove Albion'),
#             ('ENG-Premier League',                'Burnley'),
#             ...
#             (       'ITA-Serie A',                   'Roma'),
#             (       'ITA-Serie A',                   'SPAL'),
#             (       'ITA-Serie A',            'Salernitana'),
#             (       'ITA-Serie A',              'Sampdoria'),
#             (       'ITA-Serie A',               'Sassuolo'),
# ...

# %%
team_ratings_nat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33950 entries, Argentina to Wales
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   overall                      33950 non-null  object
#  1   attack                       33950 non-null  object
#  2   midfield                     33950 non-null  object
#  3   defence                      33950 non-null  object
#  4   transfer_budget              33950 non-null  object
#  5   club_worth                   33950 non-null  object
#  6   build_up_speed               33950 non-null  object
#  7   build_up_dribbling           33950 non-null  object
#  8   build_up_passing             33950 non-null  object
#  9   build_up_positioning         33950 non-null  object
#  10  chance_creation_crossing     33950 non-null  object
#  11  chance_creation_passing      33950 non-null  object
# ...

# %%
team_ratings_nat = sofifa.read_team_ratings_nationals()
team_ratings_nat
# Out:
#           overall attack midfield defence transfer_budget club_worth  \
# team
# Argentina      83     84       82      82              €0         €0
# Argentina      82     85       80      80              €0         €0
# Argentina      81     83       81      79              €0         €0
# Argentina      83     86       82      81              €0         €0
# Argentina      83     86       82      81              €0         €0
# ...           ...    ...      ...     ...             ...        ...
# Wales          74     77       74      72              €0         €0
# Wales          74     70       76      73              €0         €0
# Wales          75     82       73      77              €0         €0
# Wales          73     73       73      71              €0         €0
# Wales          74     82       71      77              €0         €0
#
#           build_up_speed build_up_dribbling build_up_passing  \
# team
# Argentina           Slow             Little            Short
# ...

# %%
team_ratings_nat
# Out:
#           overall attack midfield defence transfer_budget club_worth  \
# team
# Argentina      83     84       82      82              €0         €0
# Argentina      82     85       80      80              €0         €0
# Argentina      81     83       81      79              €0         €0
# Argentina      83     86       82      81              €0         €0
# Argentina      83     86       82      81              €0         €0
# ...           ...    ...      ...     ...             ...        ...
# Wales          74     77       74      72              €0         €0
# Wales          74     70       76      73              €0         €0
# Wales          75     82       73      77              €0         €0
# Wales          73     73       73      71              €0         €0
# Wales          74     82       71      77              €0         €0
#
#           build_up_speed build_up_dribbling build_up_passing  \
# team
# Argentina           Slow             Little            Short
# ...

# %%
team_ratings_nat
# Out:
#           overall attack midfield defence transfer_budget club_worth  \
# team
# Argentina      83     84       82      82              €0         €0
# Argentina      82     85       80      80              €0         €0
# Argentina      81     83       81      79              €0         €0
# Argentina      83     86       82      81              €0         €0
# Argentina      83     86       82      81              €0         €0
# ...           ...    ...      ...     ...             ...        ...
# Wales          74     77       74      72              €0         €0
# Wales          74     70       76      73              €0         €0
# Wales          75     82       73      77              €0         €0
# Wales          73     73       73      71              €0         €0
# Wales          74     82       71      77              €0         €0
#
#           build_up_speed build_up_dribbling build_up_passing  \
# team
# Argentina           Slow             Little            Short
# ...

# %%
team_ratings.reset_index(inplace=True)
team_ratings['update'] = team_ratings['update'].apply(lambda x: pd.to_datetime(x))
team_ratings["overall"] = team_ratings["overall"].astype(int)
team_ratings["attack"] = team_ratings["attack"].astype(int)
team_ratings["midfield"] = team_ratings["midfield"].astype(int)
team_ratings["defence"] = team_ratings["defence"].astype(int)
#team_ratings["transfer_budget"] = team_ratings["transfer_budget"].str.replace("€", "").str.replace("M", "0000").str.replace("K", "000").str.replace(".", "").astype(int)
team_ratings["club_worth"] = team_ratings["club_worth"].str.replace("€", "").str.replace("M", "0000").str.replace("K", "000").str.replace("B", "000000000").str.replace(".", "").astype(float)
team_ratings["defence_domestic_prestige"] = team_ratings["defence_domestic_prestige"].astype(int)
team_ratings["international_prestige"] = team_ratings["international_prestige"].astype(int)
team_ratings["players"] = team_ratings["players"].astype(int)
team_ratings["starting_xi_average_age"] = team_ratings["starting_xi_average_age"].astype(float)
team_ratings["whole_team_average_age"] = team_ratings["whole_team_average_age"].astype(float)
team_ratings.sort_values('update', ascending=False)

# %%
format = '%b %d, %Y'
team_ratings_nat['date_converted'] = pd.to_datetime(team_ratings_nat['update'], format=format, errors='coerce')

# Filtrer les lignes où la conversion a échoué (date_converted est NaT)
invalid_dates = team_ratings_nat[team_ratings_nat['date_converted'].isna()]
invalid_dates
# Out:
#                     overall attack midfield defence transfer_budget  \
# team
# Argentina                84     86       84      82              €0
# Australia                72     72       72      71              €0
# Austria                  77     79       77      78              €0
# Belgium                  83     84       81      79              €0
# Brazil                   85     85       85      83              €0
# Cameroon                 75     75       75      72              €0
# Canada                   75     75       78      72              €0
# China PR                 70     71       69      70              €0
# Costa Rica               74     73       73      74              €0
# Croatia                  80     80       83      78              €0
# Czech Republic           77     79       75      76              €0
# Denmark                  80     77       83      80              €0
# Ecuador                  75     75       75      75              €0
# ...

# %%
team_ratings_nat['update'] = team_ratings_nat['update'].apply(lambda x: pd.to_datetime(x))
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 team_ratings_nat['update'] = team_ratings_nat['update'].apply(lambda x: pd.to_datetime(x))
#
# File c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
team_ratings_nat[team_ratings_nat["update"].str.contains("World Cup")]
# Out:
#                     overall attack midfield defence transfer_budget  \
# team
# Argentina                84     86       84      82              €0
# Australia                72     72       72      71              €0
# Austria                  77     79       77      78              €0
# Belgium                  83     84       81      79              €0
# Brazil                   85     85       85      83              €0
# Cameroon                 75     75       75      72              €0
# Canada                   75     75       78      72              €0
# China PR                 70     71       69      70              €0
# Costa Rica               74     73       73      74              €0
# Croatia                  80     80       83      78              €0
# Czech Republic           77     79       75      76              €0
# Denmark                  80     77       83      80              €0
# Ecuador                  75     75       75      75              €0
# ...

# %%
team_ratings_nat[team_ratings_nat["update"] == "World Cup 2022"]
# Out:
#                       team overall attack midfield defence transfer_budget  \
# 118              Argentina      84     86       84      82              €0
# 1411             Australia      72     72       72      71              €0
# 1857               Austria      77     79       77      78              €0
# 2196               Belgium      83     84       81      79              €0
# 3723                Brazil      85     85       85      83              €0
# 5435              Cameroon      75     75       75      72              €0
# 5480                Canada      75     75       78      72              €0
# 6967              China PR      70     71       69      70              €0
# 7673            Costa Rica      74     73       73      74              €0
# 7707               Croatia      80     80       83      78              €0
# 8348        Czech Republic      77     79       75      76              €0
# ...

# %%
team_ratings_nat.loc[team_ratings_nat["update"] == "World Cup 2022", "update"] = "Nov 20, 2022"

# %%
team_ratings_nat.reset_index(inplace=True)
team_ratings_nat["league"] = "INT"
team_ratings_nat.loc[team_ratings_nat["update"] == "World Cup 2022", "update"] = "Nov 20, 2022"
team_ratings_nat['update'] = team_ratings_nat['update'].apply(lambda x: pd.to_datetime(x))
team_ratings_nat["overall"] = team_ratings_nat["overall"].astype(int)
team_ratings_nat["attack"] = team_ratings_nat["attack"].astype(int)
team_ratings_nat["midfield"] = team_ratings_nat["midfield"].astype(int)
team_ratings_nat["defence"] = team_ratings_nat["defence"].astype(int)
team_ratings_nat["transfer_budget"] = team_ratings_nat["transfer_budget"].str.replace("€", "").str.replace("M", "0000").str.replace("K", "000").str.replace(".", "").astype(int)
team_ratings_nat["club_worth"] = team_ratings_nat["club_worth"].apply(lambda x: str(x).replace("€", "").replace("M", "0000").replace("K", "000").replace("B", "000000000").replace(".", "")).astype(float)
team_ratings_nat["defence_domestic_prestige"] = team_ratings_nat["defence_domestic_prestige"].astype(int)
team_ratings_nat["international_prestige"] = team_ratings_nat["international_prestige"].astype(int)
team_ratings_nat["players"] = team_ratings_nat["players"].astype(int)
team_ratings_nat["starting_xi_average_age"] = team_ratings_nat["starting_xi_average_age"].astype(float)
team_ratings_nat["whole_team_average_age"] = team_ratings_nat["whole_team_average_age"].astype(float)
team_ratings_nat.sort_values('update', ascending=False, inplace=True)

# %%
team_ratings_nat["club_worth"] = team_ratings_nat["club_worth"].apply(lambda x: str(x).replace("€", "").replace("M", "0000").replace("K", "000").replace("B", "000000000").replace(".", "")).astype(float)

# %%
team_ratings_nat
# Out:
#        level_0  index       team  overall  attack  midfield  defence  \
# 0            0      0  Argentina       83      84        82       82
# 1            1      1  Argentina       82      85        80       80
# 2            2      2  Argentina       81      83        81       79
# 3            3      3  Argentina       83      86        82       81
# 4            4      4  Argentina       83      86        82       81
# ...        ...    ...        ...      ...     ...       ...      ...
# 33945    33945  33945      Wales       74      77        74       72
# 33946    33946  33946      Wales       74      70        76       73
# 33947    33947  33947      Wales       75      82        73       77
# 33948    33948  33948      Wales       73      73        73       71
# 33949    33949  33949      Wales       74      82        71       77
#
#        transfer_budget   club_worth build_up_speed  ... defence_defender_line  \
# ...

# %%
team_ratings_nat.describe()
# Out:
#               index       overall        attack      midfield       defence  \
# count  33950.000000  33950.000000  33950.000000  33950.000000  33950.000000
# mean   16974.500000     75.362121     76.050898     75.004713     74.124448
# min        0.000000     57.000000     58.000000     54.000000     53.000000
# 25%     8487.250000     72.000000     72.000000     72.000000     70.000000
# 50%    16974.500000     75.000000     76.000000     75.000000     74.000000
# 75%    25461.750000     79.000000     81.000000     79.000000     78.000000
# max    33949.000000     87.000000     91.000000     87.000000     87.000000
# std     9800.665156      5.304879      5.782013      5.566807      5.606426
#
#        transfer_budget  defence_domestic_prestige  international_prestige  \
# count     33950.000000               33950.000000             33950.00000
# mean        120.765832                  12.889249                 7.10268
# ...

# %%
team_ratings_nat.columns
# Out:
# Index(['overall', 'attack', 'midfield', 'defence', 'transfer_budget',
#        'club_worth', 'build_up_speed', 'build_up_dribbling',
#        'build_up_passing', 'build_up_positioning', 'chance_creation_crossing',
#        'chance_creation_passing', 'chance_creation_shooting',
#        'chance_creation_positioning', 'defence_aggression', 'defence_pressure',
#        'defence_team_width', 'defence_defender_line',
#        'defence_domestic_prestige', 'international_prestige', 'players',
#        'starting_xi_average_age', 'whole_team_average_age', 'fifa_edition',
#        'update'],
#       dtype='object')

# %%
team_ratings_nat.loc['France', ['overall', 'update']]
# Out:
#        overall        update
# team
# France      82  Sep 22, 2016
# France      81  Jul 10, 2015
# France      85  Mar 25, 2022
# France      84  Mar 20, 2019
# France      85  Aug 30, 2021
# ...        ...           ...
# France      82  Jul 21, 2016
# France      81   Nov 7, 2014
# France      83  Apr 17, 2023
# France      84  Jun 11, 2018
# France      82   Jul 7, 2016
#
# [762 rows x 2 columns]

# %%
#convert int
import pandas as pd
team_ratings_nat['overall'] = team_ratings_nat['overall'].astype(int)
# convert date ex: Jul 21, 2016
team_ratings_nat['year'] = team_ratings_nat['update'].apply(lambda x: int(x.split(' ')[-1]))

# %%
team_ratings_nat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33950 entries, Argentina to Wales
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   overall                      33950 non-null  int32
#  1   attack                       33950 non-null  object
#  2   midfield                     33950 non-null  object
#  3   defence                      33950 non-null  object
#  4   transfer_budget              33950 non-null  object
#  5   club_worth                   33950 non-null  object
#  6   build_up_speed               33950 non-null  object
#  7   build_up_dribbling           33950 non-null  object
#  8   build_up_passing             33950 non-null  object
#  9   build_up_positioning         33950 non-null  object
#  10  chance_creation_crossing     33950 non-null  object
#  11  chance_creation_passing      33950 non-null  object
#  12  chance_creation_shooting     33950 non-null  object
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))
team_ratings_nat.loc["France"].groupby('year')['overall'].mean().plot(ax=ax)
team_ratings_nat.loc["Germany"].groupby('year')['overall'].mean().plot(ax=ax)
team_ratings_nat.loc["Spain"].groupby('year')['overall'].mean().plot(ax=ax)
ax.set_title('Mean Team Rating Over Time')
ax.set_ylabel('Overall Rating')
ax.set_xlabel('Year')
ax.legend(['France', 'Germany', 'Spain'])
plt.show()
