# %%
import soccerdata as sd
no_cache = True
sofifa = sd.SoFIFA(versions="latest", no_cache=no_cache)
# Out:
# [06/20/24 17:28:03] INFO     No custom team name replacements found. You can configure these in       ]8;id=577682;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=50062;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\jdelavande\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=851525;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=358321;file://c:\Users\jdelavande\Projects\optim-sportbet\venv\lib\site-packages\soccerdata\_config.py#180\180]8;;\
#                              C:\Users\jdelavande\soccerdata\config\league_dict.json.
# ...

# %%
url = "https://sofifa.com/teams?type=history"
for i in range(40):
    url+= "&5B%5D=" + str(i)

url
# Out:
# 'https://sofifa.com/teams?type=history&5B%5D=0&5B%5D=1&5B%5D=2&5B%5D=3&5B%5D=4&5B%5D=5&5B%5D=6&5B%5D=7&5B%5D=8&5B%5D=9&5B%5D=10&5B%5D=11&5B%5D=12&5B%5D=13&5B%5D=14&5B%5D=15&5B%5D=16&5B%5D=17&5B%5D=18&5B%5D=19&5B%5D=20&5B%5D=21&5B%5D=22&5B%5D=23&5B%5D=24&5B%5D=25&5B%5D=26&5B%5D=27&5B%5D=28&5B%5D=29&5B%5D=30&5B%5D=31&5B%5D=32&5B%5D=33&5B%5D=34&5B%5D=35&5B%5D=36&5B%5D=37&5B%5D=38&5B%5D=39'

# %%
sofifa.read_team_ratings_nationals()
# Out:
# https://sofifa.com/teams?type=national&r=240043&set=true&showCol[]=oa&showCol[]=at&showCol[]=md&showCol[]=df&showCol[]=tb&showCol[]=cw&showCol[]=bs&showCol[]=bd&showCol[]=bp&showCol[]=bps&showCol[]=cc&showCol[]=cp&showCol[]=cs&showCol[]=cps&showCol[]=da&showCol[]=dm&showCol[]=dw&showCol[]=dd&showCol[]=dp&showCol[]=ip&showCol[]=ps&showCol[]=sa&showCol[]=ta
# https://sofifa.com/teams?type=history&r=240043&set=true&na%5B%5D=1&na%5B%5D=20&na%5B%5D=43&showCol[]=oa&showCol[]=at&showCol[]=md&showCol[]=df&showCol[]=tb&showCol[]=cw&showCol[]=bs&showCol[]=bd&showCol[]=bp&showCol[]=bps&showCol[]=cc&showCol[]=cp&showCol[]=cs&showCol[]=cps&showCol[]=da&showCol[]=dm&showCol[]=dw&showCol[]=dd&showCol[]=dp&showCol[]=ip&showCol[]=ps&showCol[]=sa&showCol[]=ta
#                     overall attack midfield defence transfer_budget  \
# team
# Albania                  73     66       73      74              €0
# Argentina                83     85       83      82              €0
# ...
